# %% [markdown]
# # Segmentation task
#
# Hi! It's a segmentation task baseline notebook.
# It include a data reader, baseline model and submission generator.
#
# You should use GPU to train your model, so we recommend using [Kaggle Notebooks](https://www.kaggle.com/docs/notebooks).
# To get maximum score of the task, your model should have IoU greater than `0.8`.
#
# You can use everything, that suits into the rules in `README.md`.

# %%
from datetime import datetime
import numpy as np
from pathlib import Path
import pandas as pd

import torch
import torch.nn as nn
from torch.utils import data

import catalyst
from catalyst import dl
from catalyst.utils import metrics, imread, set_global_seed

# %%
set_global_seed(42)

# %% [markdown]
# ## Dataset
#
# Load train data. Don't forget to add test data. Use test data, to compare methods/models/etc.

# %%
local_path = Path().cwd().parent

# %%
train_image_path = local_path / 'data3'/ Path("train") / "images"
train_mask_path = local_path / 'data3'/ Path("train") / "masks"
ALL_IMAGES = sorted(train_image_path.glob("*.png"))
ALL_MASKS = sorted(train_mask_path.glob("*.png"))

# %%
from torch.utils.data import Dataset


class SegmentationDataset(Dataset):
    def __init__(self, images=None, masks=None, transforms=None) -> None:
        self.images = images
        self.masks = masks
        self.transforms = transforms

    def __len__(self) -> int:
        return len(self.images)

    def __getitem__(self, idx: int) -> dict:
        image_path = self.images[idx]
        image = imread(image_path)

        result = {"image": image}

        if self.masks is not None:
            result["mask"] = imread(self.masks[idx]).mean(2) // 255

        if self.transforms is not None:
            result = self.transforms(**result)
            if result.get("mask", None) is not None:
                result["mask"] = result["mask"].unsqueeze(0)

        result["filename"] = image_path.name
        result["image size"] = image.shape[:2]

        return result

# %% [markdown]
# ## Augmentations
#
# To train an accurate model for a segmentation task, you need a lot of data.
# Use data augmentations to simulate a bigger dataset.

# %%
import albumentations as albu
from albumentations.pytorch import ToTensorV2 as ToTensor
import cv2

IMAGE_SIZE = 256
train_transform = albu.Compose([
    albu.HorizontalFlip(p=0.5),
    albu.VerticalFlip(p=0.5),
    albu.RandomRotate90(p=0.5),
    albu.Resize(IMAGE_SIZE, IMAGE_SIZE),
    albu.RandomResizedCrop(IMAGE_SIZE, IMAGE_SIZE, p=0.5),
    albu.Normalize(),
    ToTensor()
])

valid_transform = albu.Compose([
    albu.Resize(IMAGE_SIZE, IMAGE_SIZE),
    albu.RandomResizedCrop(IMAGE_SIZE, IMAGE_SIZE, p=0.25),
    albu.Normalize(),
    ToTensor()
])

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader

batch_size = 8
num_workers = 4

indices = np.arange(len(ALL_IMAGES))

train_indices, valid_indices = train_test_split(
    indices, test_size=0.2, random_state=42, shuffle=True
)

np_images = np.array(ALL_IMAGES)
np_masks = np.array(ALL_MASKS)

train_dataset = SegmentationDataset(
    images = np_images[train_indices].tolist(),
    masks = np_masks[train_indices].tolist(),
    transforms = train_transform
)

valid_dataset = SegmentationDataset(
    images = np_images[valid_indices].tolist(),
    masks = np_masks[valid_indices].tolist(),
    transforms = valid_transform
)

loaders = {
    "train": DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        drop_last=True,
    ),
    "valid": DataLoader(
        valid_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        drop_last=True,
    )
}

# %% [markdown]
# Our current baseline model is `U-Net`.
# You can do anything with it: add pretrained backbone, make model wider or deeper or change a model architecture.
# You can use `torchvision` module to create a backbone, but not a whole model.

# %%
from GaborNet import GaborConv2d

# %%
class Baseline(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.gl = nn.Sequential(
            GaborConv2d(3, 32, kernel_size=15, padding=7),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(),
            nn.Conv2d(32, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(),
        )
        
        self.down_1 = self.make_down_layer_(32, 64)
        self.down_2 = self.make_down_layer_(64, 128)
        self.down_3 = self.make_down_layer_(128, 256)
        '''self.down_4 = self.make_down_layer_(128, 256)
        
        self.up_1 = self.make_up_layer_(256, 128)'''
        self.up_2 = self.make_up_layer_(256, 128)
        self.up_3 = self.make_up_layer_(128, 64)
        self.up_4 = self.make_up_layer_(64, 32)
        
        self.out = nn.Sequential(
            nn.Conv2d(32, 1, kernel_size=1)
        )

    def make_down_layer_(self, in_channels, out_channels):
        return nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        )

    def make_up_layer_(self, in_channels, out_channels):
        return nn.ModuleList(
            [
                nn.ConvTranspose2d(
                    in_channels,
                    out_channels,
                    kernel_size=3,
                    stride=2,
                    padding=1,
                    output_padding=1,
                ),
                nn.Conv2d(
                    2 * out_channels,
                    out_channels,
                    kernel_size=3,
                    stride=1,
                    padding=1,
                ),
                nn.BatchNorm2d(out_channels),
                nn.LeakyReLU(),
                nn.Conv2d(
                    out_channels,
                    out_channels,
                    kernel_size=3,
                    stride=1,
                    padding=1,
                ),
                nn.BatchNorm2d(out_channels),
                nn.LeakyReLU(),
            ]
        )

    def forward(self, image):
        x_0 = self.gl(image)
        
        x_1 = self.down_1(x_0)
        x_2 = self.down_2(x_1)
        x_3 = self.down_3(x_2)
        '''x_4 = self.down_4(x_3)

        u_1 = self.up_1[0](x_4)
        u_1 = torch.cat([x_3, u_1], axis=1)
        for m in self.up_1[1:]:
            u_1 = m(u_1)'''
        
        u_2 = self.up_2[0](x_3)
        u_2 = torch.cat([x_2, u_2], axis=1)
        for m in self.up_2[1:]:
            u_2 = m(u_2)

        u_3 = self.up_3[0](u_2)
        u_3 = torch.cat([x_1, u_3], axis=1)
        for m in self.up_3[1:]:
            u_3 = m(u_3)
            
        u_4 = self.up_4[0](u_3)
        u_4 = torch.cat([x_0, u_4], axis=1)
        for m in self.up_4[1:]:
            u_4 = m(u_4)
        
        return self.out(u_4)

# %%
'''inp = iter(loaders['train']).next()['image']
model = Baseline()
out = model(inp)
out.shape'''
# Out:
# "inp = iter(loaders['train']).next()['image']\nmodel = Baseline()\nout = model(inp)\nout.shape"

# %%
from catalyst.contrib.nn import DiceLoss, IoULoss
from catalyst.dl.runner import SupervisedRunner
from torch.nn.functional import interpolate
from catalyst.contrib.nn import RAdam, Lookahead


class SegmentationRunner(SupervisedRunner):
    def predict_batch(self, batch):
        prediction = {"filename": batch["filename"]}
        masks = self.model(batch[self.input_key].to(self.device))
        image_size = list(zip(*batch["image size"]))
        prediction["mask"] = [
            interpolate(mask.unsqueeze(0), image_size).squeeze(0)
            for mask, image_size in zip(masks, image_size)
        ]
        return prediction

# we have multiple criterions
model = Baseline()
criterion = {
    "dice": DiceLoss(),
    "iou": IoULoss(),
    "bce": nn.BCEWithLogitsLoss()
}

base_optimizer = RAdam(model.parameters(), lr=0.001, weight_decay=0.0003)
optimizer = Lookahead(base_optimizer)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=0.5, patience=2, min_lr=1e-8, mode='max')

runner = SegmentationRunner(input_key="image", input_target_key="mask")

# %%
callbacks = [
    dl.CriterionCallback(
        input_key="mask", prefix="loss_dice", criterion_key="dice"
    ),
    dl.CriterionCallback(
        input_key="mask", prefix="loss_iou", criterion_key="iou"
    ),
    dl.CriterionCallback(
        input_key="mask", prefix="loss_bce", criterion_key="bce"
    ),
    dl.MetricAggregationCallback(
        prefix="loss",
        mode="weighted_sum",
        metrics={"loss_dice": 1.0, "loss_iou": 1.0, "loss_bce": 0.8},
    ),
    dl.DiceCallback(input_key="mask"),
    dl.IouCallback(input_key="mask"),
    dl.OptimizerCallback(
            metric_key="loss", accumulation_steps=1, grad_clip_params=None,
        )
]

# %%
runner.train(
    model=model,
    criterion=criterion,
    optimizer=optimizer,
    scheduler=scheduler,
    loaders=loaders,
    callbacks=callbacks,
    logdir=Path("logs") / datetime.now().strftime("%Y%m%d-%H%M%S"),
    num_epochs=100,
    main_metric="iou", # kaggle competition metric
    minimize_metric=False,
    verbose=True,
)
# Out:
# 1/100 * Epoch (train):   0% 0/41 [00:00<?, ?it/s]
# /home/analekseev/.cache/pypoetry/virtualenvs/dl-course-SIh-1RzJ-py3.8/lib/python3.8/site-packages/catalyst/callbacks/optimizer.py:140: UserWarning:
#
# This overload of add is deprecated:
# 	add(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
# 1/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.92it/s, dice=0.634, iou=0.464, loss=1.277, loss_bce=0.469, loss_dice=0.366, loss_iou=0.536]
# 1/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.41it/s, dice=0.402, iou=0.252, loss=1.845, loss_bce=0.623, loss_dice=0.598, loss_iou=0.748]
# [2020-10-18 04:46:04,254]
# 1/100 * Epoch 1 (_base): lr=0.0010 | momentum=0.9000
# 1/100 * Epoch 1 (train): dice=0.4809 | iou=0.3193 | loss=1.7108 | loss_bce=0.6387 | loss_dice=0.5191 | loss_iou=0.6807
# 1/100 * Epoch 1 (valid): dice=0.5075 | iou=0.3444 | loss=1.6019 | loss_bce=0.5673 | loss_dice=0.4925 | loss_iou=0.6556
# 2/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.93it/s, dice=0.523, iou=0.354, loss=1.598, loss_bce=0.594, loss_dice=0.477, loss_iou=0.646]
# 2/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.56it/s, dice=0.548, iou=0.378, loss=1.544, loss_bce=0.588, loss_dice=0.452, loss_iou=0.622]
# [2020-10-18 04:46:27,893]
# 2/100 * Epoch 2 (_base): lr=0.0010 | momentum=0.9000
# 2/100 * Epoch 2 (train): dice=0.6254 | iou=0.4582 | loss=1.2824 | loss_bce=0.4575 | loss_dice=0.3746 | loss_iou=0.5418
# 2/100 * Epoch 2 (valid): dice=0.6522 | iou=0.4881 | loss=1.2216 | loss_bce=0.4524 | loss_dice=0.3478 | loss_iou=0.5119
# 3/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.92it/s, dice=0.602, iou=0.431, loss=1.358, loss_bce=0.490, loss_dice=0.398, loss_iou=0.569]
# 3/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.47it/s, dice=0.578, iou=0.406, loss=1.402, loss_bce=0.482, loss_dice=0.422, loss_iou=0.594]
# [2020-10-18 04:46:51,778]
# 3/100 * Epoch 3 (_base): lr=0.0010 | momentum=0.9000
# 3/100 * Epoch 3 (train): dice=0.6698 | iou=0.5070 | loss=1.1365 | loss_bce=0.3916 | loss_dice=0.3302 | loss_iou=0.4930
# 3/100 * Epoch 3 (valid): dice=0.6821 | iou=0.5219 | loss=1.1013 | loss_bce=0.3816 | loss_dice=0.3179 | loss_iou=0.4781
# 4/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.93it/s, dice=0.688, iou=0.524, loss=1.067, loss_bce=0.348, loss_dice=0.312, loss_iou=0.476]
# 4/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.33it/s, dice=0.549, iou=0.378, loss=1.406, loss_bce=0.416, loss_dice=0.451, loss_iou=0.622]
# [2020-10-18 04:47:15,698]
# 4/100 * Epoch 4 (_base): lr=0.0010 | momentum=0.9000
# 4/100 * Epoch 4 (train): dice=0.6928 | iou=0.5320 | loss=1.0647 | loss_bce=0.3618 | loss_dice=0.3072 | loss_iou=0.4680
# 4/100 * Epoch 4 (valid): dice=0.6982 | iou=0.5424 | loss=1.0377 | loss_bce=0.3478 | loss_dice=0.3018 | loss_iou=0.4576
# 5/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.91it/s, dice=0.632, iou=0.462, loss=1.202, loss_bce=0.370, loss_dice=0.368, loss_iou=0.538]
# 5/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.02it/s, dice=0.570, iou=0.399, loss=1.397, loss_bce=0.457, loss_dice=0.430, loss_iou=0.601]
# [2020-10-18 04:47:39,964]
# 5/100 * Epoch 5 (_base): lr=0.0010 | momentum=0.9000
# 5/100 * Epoch 5 (train): dice=0.7105 | iou=0.5544 | loss=1.0075 | loss_bce=0.3405 | loss_dice=0.2895 | loss_iou=0.4456
# 5/100 * Epoch 5 (valid): dice=0.6955 | iou=0.5374 | loss=1.0455 | loss_bce=0.3480 | loss_dice=0.3045 | loss_iou=0.4626
# 6/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.91it/s, dice=0.803, iou=0.671, loss=0.726, loss_bce=0.250, loss_dice=0.197, loss_iou=0.329]
# 6/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.43it/s, dice=0.574, iou=0.403, loss=1.337, loss_bce=0.393, loss_dice=0.426, loss_iou=0.597]
# [2020-10-18 04:48:04,204]
# 6/100 * Epoch 6 (_base): lr=0.0010 | momentum=0.9000
# 6/100 * Epoch 6 (train): dice=0.7320 | iou=0.5799 | loss=0.9420 | loss_bce=0.3174 | loss_dice=0.2680 | loss_iou=0.4201
# 6/100 * Epoch 6 (valid): dice=0.7207 | iou=0.5692 | loss=0.9425 | loss_bce=0.2905 | loss_dice=0.2793 | loss_iou=0.4308
# 7/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.92it/s, dice=0.780, iou=0.639, loss=0.776, loss_bce=0.243, loss_dice=0.220, loss_iou=0.361]
# 7/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.43it/s, dice=0.632, iou=0.462, loss=1.257, loss_bce=0.439, loss_dice=0.368, loss_iou=0.538]
# [2020-10-18 04:48:28,192]
# 7/100 * Epoch 7 (_base): lr=0.0010 | momentum=0.9000
# 7/100 * Epoch 7 (train): dice=0.7309 | iou=0.5796 | loss=0.9459 | loss_bce=0.3204 | loss_dice=0.2691 | loss_iou=0.4204
# 7/100 * Epoch 7 (valid): dice=0.7187 | iou=0.5669 | loss=1.0080 | loss_bce=0.3671 | loss_dice=0.2813 | loss_iou=0.4331
# 8/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.92it/s, dice=0.793, iou=0.657, loss=0.749, loss_bce=0.248, loss_dice=0.207, loss_iou=0.343]
# 8/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.35it/s, dice=0.631, iou=0.461, loss=1.224, loss_bce=0.395, loss_dice=0.369, loss_iou=0.539]
# [2020-10-18 04:48:52,105]
# 8/100 * Epoch 8 (_base): lr=0.0010 | momentum=0.9000
# 8/100 * Epoch 8 (train): dice=0.7474 | iou=0.5998 | loss=0.8880 | loss_bce=0.2940 | loss_dice=0.2526 | loss_iou=0.4002
# 8/100 * Epoch 8 (valid): dice=0.7224 | iou=0.5711 | loss=0.9528 | loss_bce=0.3078 | loss_dice=0.2776 | loss_iou=0.4289
# 9/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.92it/s, dice=0.650, iou=0.482, loss=1.220, loss_bce=0.440, loss_dice=0.350, loss_iou=0.518]
# 9/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.34it/s, dice=0.520, iou=0.352, loss=1.920, loss_bce=0.990, loss_dice=0.480, loss_iou=0.648]
# [2020-10-18 04:49:16,170]
# 9/100 * Epoch 9 (_base): lr=0.0010 | momentum=0.9000
# 9/100 * Epoch 9 (train): dice=0.7598 | iou=0.6176 | loss=0.8523 | loss_bce=0.2872 | loss_dice=0.2402 | loss_iou=0.3824
# 9/100 * Epoch 9 (valid): dice=0.6402 | iou=0.4753 | loss=1.5709 | loss_bce=0.8580 | loss_dice=0.3598 | loss_iou=0.5247
# 10/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.92it/s, dice=0.801, iou=0.667, loss=0.680, loss_bce=0.186, loss_dice=0.199, loss_iou=0.333]
# 10/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.41it/s, dice=0.607, iou=0.436, loss=1.292, loss_bce=0.419, loss_dice=0.393, loss_iou=0.564]
# [2020-10-18 04:49:39,998]
# 10/100 * Epoch 10 (_base): lr=0.0010 | momentum=0.9000
# 10/100 * Epoch 10 (train): dice=0.7717 | iou=0.6310 | loss=0.8237 | loss_bce=0.2829 | loss_dice=0.2283 | loss_iou=0.3690
# 10/100 * Epoch 10 (valid): dice=0.7677 | iou=0.6295 | loss=0.8306 | loss_bce=0.2848 | loss_dice=0.2323 | loss_iou=0.3705
# 11/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.89it/s, dice=0.805, iou=0.674, loss=0.728, loss_bce=0.259, loss_dice=0.195, loss_iou=0.326]
# 11/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.35it/s, dice=0.668, iou=0.501, loss=1.101, loss_bce=0.337, loss_dice=0.332, loss_iou=0.499]
# [2020-10-18 04:50:04,308]
# 11/100 * Epoch 11 (_base): lr=0.0010 | momentum=0.9000
# 11/100 * Epoch 11 (train): dice=0.7899 | iou=0.6556 | loss=0.7706 | loss_bce=0.2701 | loss_dice=0.2101 | loss_iou=0.3444
# 11/100 * Epoch 11 (valid): dice=0.7637 | iou=0.6223 | loss=0.8204 | loss_bce=0.2581 | loss_dice=0.2363 | loss_iou=0.3777
# 12/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.86it/s, dice=0.820, iou=0.696, loss=0.701, loss_bce=0.271, loss_dice=0.180, loss_iou=0.304]
# 12/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.35it/s, dice=0.723, iou=0.566, loss=0.936, loss_bce=0.280, loss_dice=0.277, loss_iou=0.434]
# [2020-10-18 04:50:28,927]
# 12/100 * Epoch 12 (_base): lr=0.0010 | momentum=0.9000
# 12/100 * Epoch 12 (train): dice=0.7937 | iou=0.6625 | loss=0.7550 | loss_bce=0.2639 | loss_dice=0.2063 | loss_iou=0.3375
# 12/100 * Epoch 12 (valid): dice=0.7911 | iou=0.6597 | loss=0.7446 | loss_bce=0.2443 | loss_dice=0.2089 | loss_iou=0.3403
# 13/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.90it/s, dice=0.901, iou=0.819, loss=0.391, loss_bce=0.138, loss_dice=0.099, loss_iou=0.181]
# 13/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.34it/s, dice=0.708, iou=0.548, loss=1.110, loss_bce=0.458, loss_dice=0.292, loss_iou=0.452]
# [2020-10-18 04:50:53,129]
# 13/100 * Epoch 13 (_base): lr=0.0010 | momentum=0.9000
# 13/100 * Epoch 13 (train): dice=0.8058 | iou=0.6787 | loss=0.7122 | loss_bce=0.2459 | loss_dice=0.1942 | loss_iou=0.3213
# 13/100 * Epoch 13 (valid): dice=0.7965 | iou=0.6670 | loss=0.7452 | loss_bce=0.2608 | loss_dice=0.2035 | loss_iou=0.3330
# 14/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.90it/s, dice=0.787, iou=0.649, loss=0.765, loss_bce=0.252, loss_dice=0.213, loss_iou=0.351]
# 14/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.28it/s, dice=0.718, iou=0.560, loss=1.041, loss_bce=0.398, loss_dice=0.282, loss_iou=0.440]
# [2020-10-18 04:51:17,382]
# 14/100 * Epoch 14 (_base): lr=0.0010 | momentum=0.9000
# 14/100 * Epoch 14 (train): dice=0.8248 | iou=0.7042 | loss=0.6564 | loss_bce=0.2317 | loss_dice=0.1752 | loss_iou=0.2958
# 14/100 * Epoch 14 (valid): dice=0.8019 | iou=0.6752 | loss=0.7377 | loss_bce=0.2685 | loss_dice=0.1981 | loss_iou=0.3248
# 15/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.81it/s, dice=0.854, iou=0.745, loss=0.565, loss_bce=0.206, loss_dice=0.146, loss_iou=0.255]
# 15/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.50it/s, dice=0.732, iou=0.577, loss=0.912, loss_bce=0.275, loss_dice=0.268, loss_iou=0.423]
# [2020-10-18 04:51:42,612]
# 15/100 * Epoch 15 (_base): lr=0.0010 | momentum=0.9000
# 15/100 * Epoch 15 (train): dice=0.8320 | iou=0.7152 | loss=0.6320 | loss_bce=0.2241 | loss_dice=0.1680 | loss_iou=0.2848
# 15/100 * Epoch 15 (valid): dice=0.7934 | iou=0.6590 | loss=0.7409 | loss_bce=0.2415 | loss_dice=0.2066 | loss_iou=0.3410
# 16/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.90it/s, dice=0.838, iou=0.722, loss=0.605, loss_bce=0.207, loss_dice=0.162, loss_iou=0.278]
# 16/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.43it/s, dice=0.740, iou=0.587, loss=0.905, loss_bce=0.290, loss_dice=0.260, loss_iou=0.413]
# [2020-10-18 04:52:06,660]
# 16/100 * Epoch 16 (_base): lr=0.0010 | momentum=0.9000
# 16/100 * Epoch 16 (train): dice=0.8288 | iou=0.7141 | loss=0.6476 | loss_bce=0.2381 | loss_dice=0.1712 | loss_iou=0.2859
# 16/100 * Epoch 16 (valid): dice=0.8332 | iou=0.7182 | loss=0.6152 | loss_bce=0.2083 | loss_dice=0.1668 | loss_iou=0.2818
# 17/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.90it/s, dice=0.798, iou=0.664, loss=0.817, loss_bce=0.348, loss_dice=0.202, loss_iou=0.336]
# 17/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.39it/s, dice=0.765, iou=0.619, loss=0.935, loss_bce=0.398, loss_dice=0.235, loss_iou=0.381]
# [2020-10-18 04:52:30,842]
# 17/100 * Epoch 17 (_base): lr=0.0010 | momentum=0.9000
# 17/100 * Epoch 17 (train): dice=0.8406 | iou=0.7280 | loss=0.6176 | loss_bce=0.2327 | loss_dice=0.1594 | loss_iou=0.2720
# 17/100 * Epoch 17 (valid): dice=0.8120 | iou=0.6894 | loss=0.7479 | loss_bce=0.3117 | loss_dice=0.1880 | loss_iou=0.3106
# 18/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.89it/s, dice=0.801, iou=0.668, loss=0.767, loss_bce=0.295, loss_dice=0.199, loss_iou=0.332]
# 18/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.34it/s, dice=0.812, iou=0.684, loss=0.676, loss_bce=0.215, loss_dice=0.188, loss_iou=0.316]
# [2020-10-18 04:52:55,011]
# 18/100 * Epoch 18 (_base): lr=0.0010 | momentum=0.9000
# 18/100 * Epoch 18 (train): dice=0.8421 | iou=0.7304 | loss=0.6150 | loss_bce=0.2345 | loss_dice=0.1579 | loss_iou=0.2696
# 18/100 * Epoch 18 (valid): dice=0.8359 | iou=0.7225 | loss=0.6069 | loss_bce=0.2066 | loss_dice=0.1641 | loss_iou=0.2775
# 19/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.82it/s, dice=0.844, iou=0.731, loss=0.573, loss_bce=0.185, loss_dice=0.156, loss_iou=0.269]
# 19/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.33it/s, dice=0.756, iou=0.608, loss=0.838, loss_bce=0.252, loss_dice=0.244, loss_iou=0.392]
# [2020-10-18 04:53:20,147]
# 19/100 * Epoch 19 (_base): lr=0.0010 | momentum=0.9000
# 19/100 * Epoch 19 (train): dice=0.8370 | iou=0.7231 | loss=0.6316 | loss_bce=0.2396 | loss_dice=0.1630 | loss_iou=0.2769
# 19/100 * Epoch 19 (valid): dice=0.8247 | iou=0.7037 | loss=0.6484 | loss_bce=0.2210 | loss_dice=0.1753 | loss_iou=0.2963
# 20/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.85it/s, dice=0.848, iou=0.736, loss=0.559, loss_bce=0.178, loss_dice=0.152, loss_iou=0.264]
# 20/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.27it/s, dice=0.744, iou=0.593, loss=0.939, loss_bce=0.345, loss_dice=0.256, loss_iou=0.407]
# [2020-10-18 04:53:44,919]
# 20/100 * Epoch 20 (_base): lr=0.0010 | momentum=0.9000
# 20/100 * Epoch 20 (train): dice=0.8468 | iou=0.7387 | loss=0.5901 | loss_bce=0.2195 | loss_dice=0.1532 | loss_iou=0.2613
# 20/100 * Epoch 20 (valid): dice=0.8389 | iou=0.7270 | loss=0.6096 | loss_bce=0.2193 | loss_dice=0.1611 | loss_iou=0.2730
# 21/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.89it/s, dice=0.831, iou=0.711, loss=0.621, loss_bce=0.204, loss_dice=0.169, loss_iou=0.289]
# 21/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.23it/s, dice=0.783, iou=0.643, loss=0.765, loss_bce=0.239, loss_dice=0.217, loss_iou=0.357]
# [2020-10-18 04:54:09,363]
# 21/100 * Epoch 21 (_base): lr=0.0010 | momentum=0.9000
# 21/100 * Epoch 21 (train): dice=0.8448 | iou=0.7346 | loss=0.6128 | loss_bce=0.2404 | loss_dice=0.1552 | loss_iou=0.2654
# 21/100 * Epoch 21 (valid): dice=0.8392 | iou=0.7281 | loss=0.6279 | loss_bce=0.2439 | loss_dice=0.1608 | loss_iou=0.2719
# 22/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.90it/s, dice=0.804, iou=0.673, loss=0.638, loss_bce=0.144, loss_dice=0.196, loss_iou=0.327]
# 22/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.29it/s, dice=0.799, iou=0.666, loss=0.757, loss_bce=0.278, loss_dice=0.201, loss_iou=0.334]
# [2020-10-18 04:54:33,603]
# 22/100 * Epoch 22 (_base): lr=0.0010 | momentum=0.9000
# 22/100 * Epoch 22 (train): dice=0.8469 | iou=0.7387 | loss=0.6017 | loss_bce=0.2341 | loss_dice=0.1531 | loss_iou=0.2613
# 22/100 * Epoch 22 (valid): dice=0.8474 | iou=0.7384 | loss=0.6056 | loss_bce=0.2391 | loss_dice=0.1526 | loss_iou=0.2616
# 23/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.85it/s, dice=0.900, iou=0.818, loss=0.363, loss_bce=0.101, loss_dice=0.100, loss_iou=0.182]
# 23/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.24it/s, dice=0.773, iou=0.631, loss=0.814, loss_bce=0.272, loss_dice=0.227, loss_iou=0.369]
# [2020-10-18 04:54:58,451]
# 23/100 * Epoch 23 (_base): lr=0.0010 | momentum=0.9000
# 23/100 * Epoch 23 (train): dice=0.8566 | iou=0.7512 | loss=0.5654 | loss_bce=0.2164 | loss_dice=0.1434 | loss_iou=0.2488
# 23/100 * Epoch 23 (valid): dice=0.8514 | iou=0.7442 | loss=0.5586 | loss_bce=0.1928 | loss_dice=0.1486 | loss_iou=0.2558
# 24/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.88it/s, dice=0.866, iou=0.764, loss=0.514, loss_bce=0.180, loss_dice=0.134, loss_iou=0.236]
# 24/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.27it/s, dice=0.786, iou=0.648, loss=0.732, loss_bce=0.207, loss_dice=0.214, loss_iou=0.352]
# [2020-10-18 04:55:22,946]
# 24/100 * Epoch 24 (_base): lr=0.0010 | momentum=0.9000
# 24/100 * Epoch 24 (train): dice=0.8662 | iou=0.7663 | loss=0.5343 | loss_bce=0.2085 | loss_dice=0.1338 | loss_iou=0.2337
# 24/100 * Epoch 24 (valid): dice=0.8726 | iou=0.7762 | loss=0.4871 | loss_bce=0.1700 | loss_dice=0.1274 | loss_iou=0.2238
# 25/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.89it/s, dice=0.872, iou=0.773, loss=0.519, loss_bce=0.206, loss_dice=0.128, loss_iou=0.227]
# 25/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.18it/s, dice=0.781, iou=0.641, loss=0.778, loss_bce=0.250, loss_dice=0.219, loss_iou=0.359]
# [2020-10-18 04:55:47,433]
# 25/100 * Epoch 25 (_base): lr=0.0010 | momentum=0.9000
# 25/100 * Epoch 25 (train): dice=0.8758 | iou=0.7824 | loss=0.5027 | loss_bce=0.2011 | loss_dice=0.1242 | loss_iou=0.2176
# 25/100 * Epoch 25 (valid): dice=0.8560 | iou=0.7517 | loss=0.5753 | loss_bce=0.2287 | loss_dice=0.1440 | loss_iou=0.2483
# 26/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.84it/s, dice=0.840, iou=0.723, loss=0.779, loss_bce=0.428, loss_dice=0.160, loss_iou=0.277]
# 26/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.15it/s, dice=0.800, iou=0.667, loss=0.723, loss_bce=0.238, loss_dice=0.200, loss_iou=0.333]
# [2020-10-18 04:56:12,727]
# 26/100 * Epoch 26 (_base): lr=0.0010 | momentum=0.9000
# 26/100 * Epoch 26 (train): dice=0.8656 | iou=0.7668 | loss=0.5474 | loss_bce=0.2249 | loss_dice=0.1344 | loss_iou=0.2332
# 26/100 * Epoch 26 (valid): dice=0.8709 | iou=0.7747 | loss=0.4977 | loss_bce=0.1791 | loss_dice=0.1291 | loss_iou=0.2253
# 27/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.89it/s, dice=0.894, iou=0.808, loss=0.461, loss_bce=0.203, loss_dice=0.106, loss_iou=0.192]
# 27/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.19it/s, dice=0.825, iou=0.703, loss=0.711, loss_bce=0.299, loss_dice=0.175, loss_iou=0.297]
# [2020-10-18 04:56:37,063]
# 27/100 * Epoch 27 (_base): lr=0.0010 | momentum=0.9000
# 27/100 * Epoch 27 (train): dice=0.8606 | iou=0.7597 | loss=0.5662 | loss_bce=0.2332 | loss_dice=0.1394 | loss_iou=0.2403
# 27/100 * Epoch 27 (valid): dice=0.8789 | iou=0.7870 | loss=0.4886 | loss_bce=0.1931 | loss_dice=0.1211 | loss_iou=0.2130
# 28/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.87it/s, dice=0.858, iou=0.751, loss=0.611, loss_bce=0.276, loss_dice=0.142, loss_iou=0.249]
# 28/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.37it/s, dice=0.827, iou=0.705, loss=0.593, loss_bce=0.156, loss_dice=0.173, loss_iou=0.295]
# [2020-10-18 04:57:01,576]
# 28/100 * Epoch 28 (_base): lr=0.0010 | momentum=0.9000
# 28/100 * Epoch 28 (train): dice=0.8787 | iou=0.7881 | loss=0.4902 | loss_bce=0.1961 | loss_dice=0.1213 | loss_iou=0.2119
# 28/100 * Epoch 28 (valid): dice=0.8603 | iou=0.7569 | loss=0.5453 | loss_bce=0.2032 | loss_dice=0.1397 | loss_iou=0.2431
# 29/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.86it/s, dice=0.899, iou=0.817, loss=0.402, loss_bce=0.147, loss_dice=0.101, loss_iou=0.183]
# 29/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.27it/s, dice=0.804, iou=0.673, loss=0.727, loss_bce=0.255, loss_dice=0.196, loss_iou=0.327]
# [2020-10-18 04:57:26,135]
# 29/100 * Epoch 29 (_base): lr=0.0010 | momentum=0.9000
# 29/100 * Epoch 29 (train): dice=0.8837 | iou=0.7940 | loss=0.4787 | loss_bce=0.1956 | loss_dice=0.1163 | loss_iou=0.2060
# 29/100 * Epoch 29 (valid): dice=0.8778 | iou=0.7859 | loss=0.4924 | loss_bce=0.1951 | loss_dice=0.1222 | loss_iou=0.2141
# 30/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.87it/s, dice=0.881, iou=0.788, loss=0.485, loss_bce=0.193, loss_dice=0.119, loss_iou=0.212]
# 30/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.39it/s, dice=0.797, iou=0.662, loss=0.747, loss_bce=0.257, loss_dice=0.203, loss_iou=0.338]
# [2020-10-18 04:57:50,622]
# 30/100 * Epoch 30 (_base): lr=0.0005 | momentum=0.9000
# 30/100 * Epoch 30 (train): dice=0.8721 | iou=0.7771 | loss=0.5274 | loss_bce=0.2208 | loss_dice=0.1279 | loss_iou=0.2229
# 30/100 * Epoch 30 (valid): dice=0.8669 | iou=0.7692 | loss=0.5216 | loss_bce=0.1972 | loss_dice=0.1331 | loss_iou=0.2308
# 31/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.87it/s, dice=0.911, iou=0.836, loss=0.332, loss_bce=0.099, loss_dice=0.089, loss_iou=0.164]
# 31/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.37it/s, dice=0.818, iou=0.692, loss=0.673, loss_bce=0.228, loss_dice=0.182, loss_iou=0.308]
# [2020-10-18 04:58:15,095]
# 31/100 * Epoch 31 (_base): lr=0.0005 | momentum=0.9000
# 31/100 * Epoch 31 (train): dice=0.8851 | iou=0.7966 | loss=0.4757 | loss_bce=0.1967 | loss_dice=0.1149 | loss_iou=0.2034
# 31/100 * Epoch 31 (valid): dice=0.8795 | iou=0.7878 | loss=0.4878 | loss_bce=0.1938 | loss_dice=0.1205 | loss_iou=0.2122
# 32/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.86it/s, dice=0.939, iou=0.885, loss=0.230, loss_bce=0.068, loss_dice=0.061, loss_iou=0.115]
# 32/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.38it/s, dice=0.805, iou=0.674, loss=0.756, loss_bce=0.295, loss_dice=0.195, loss_iou=0.326]
# [2020-10-18 04:58:39,785]
# 32/100 * Epoch 32 (_base): lr=0.0005 | momentum=0.9000
# 32/100 * Epoch 32 (train): dice=0.8847 | iou=0.7980 | loss=0.4700 | loss_bce=0.1909 | loss_dice=0.1153 | loss_iou=0.2020
# 32/100 * Epoch 32 (valid): dice=0.8835 | iou=0.7959 | loss=0.4807 | loss_bce=0.2002 | loss_dice=0.1165 | loss_iou=0.2041
# 33/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.86it/s, dice=0.880, iou=0.785, loss=0.526, loss_bce=0.239, loss_dice=0.120, loss_iou=0.215]
# 33/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.38it/s, dice=0.788, iou=0.650, loss=0.820, loss_bce=0.322, loss_dice=0.212, loss_iou=0.350]
# [2020-10-18 04:59:04,651]
# 33/100 * Epoch 33 (_base): lr=0.0005 | momentum=0.9000
# 33/100 * Epoch 33 (train): dice=0.8886 | iou=0.8014 | loss=0.4583 | loss_bce=0.1854 | loss_dice=0.1114 | loss_iou=0.1986
# 33/100 * Epoch 33 (valid): dice=0.8903 | iou=0.8053 | loss=0.4456 | loss_bce=0.1765 | loss_dice=0.1097 | loss_iou=0.1947
# 34/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.86it/s, dice=0.912, iou=0.838, loss=0.315, loss_bce=0.081, loss_dice=0.088, loss_iou=0.162]
# 34/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.38it/s, dice=0.818, iou=0.693, loss=0.673, loss_bce=0.230, loss_dice=0.182, loss_iou=0.307]
# [2020-10-18 04:59:29,582]
# 34/100 * Epoch 34 (_base): lr=0.0005 | momentum=0.9000
# 34/100 * Epoch 34 (train): dice=0.8964 | iou=0.8139 | loss=0.4328 | loss_bce=0.1790 | loss_dice=0.1036 | loss_iou=0.1861
# 34/100 * Epoch 34 (valid): dice=0.8979 | iou=0.8182 | loss=0.4060 | loss_bce=0.1527 | loss_dice=0.1021 | loss_iou=0.1818
# 35/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.80it/s, dice=0.928, iou=0.866, loss=0.320, loss_bce=0.142, loss_dice=0.072, loss_iou=0.134]
# 35/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.19it/s, dice=0.843, iou=0.728, loss=0.594, loss_bce=0.206, loss_dice=0.157, loss_iou=0.272]
# [2020-10-18 04:59:55,072]
# 35/100 * Epoch 35 (_base): lr=0.0005 | momentum=0.9000
# 35/100 * Epoch 35 (train): dice=0.8942 | iou=0.8106 | loss=0.4420 | loss_bce=0.1835 | loss_dice=0.1058 | loss_iou=0.1894
# 35/100 * Epoch 35 (valid): dice=0.8916 | iou=0.8068 | loss=0.4673 | loss_bce=0.2071 | loss_dice=0.1084 | loss_iou=0.1932
# 36/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.88it/s, dice=0.927, iou=0.863, loss=0.300, loss_bce=0.112, loss_dice=0.073, loss_iou=0.137]
# 36/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.21it/s, dice=0.839, iou=0.723, loss=0.621, loss_bce=0.228, loss_dice=0.161, loss_iou=0.277]
# [2020-10-18 05:00:19,557]
# 36/100 * Epoch 36 (_base): lr=0.0005 | momentum=0.9000
# 36/100 * Epoch 36 (train): dice=0.8942 | iou=0.8104 | loss=0.4347 | loss_bce=0.1741 | loss_dice=0.1058 | loss_iou=0.1896
# 36/100 * Epoch 36 (valid): dice=0.8955 | iou=0.8129 | loss=0.4233 | loss_bce=0.1646 | loss_dice=0.1045 | loss_iou=0.1871
# 37/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.83it/s, dice=0.890, iou=0.801, loss=0.429, loss_bce=0.150, loss_dice=0.110, loss_iou=0.199]
# 37/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  3.92it/s, dice=0.828, iou=0.707, loss=0.656, loss_bce=0.239, loss_dice=0.172, loss_iou=0.293]
# [2020-10-18 05:00:44,710]
# 37/100 * Epoch 37 (_base): lr=0.0003 | momentum=0.9000
# 37/100 * Epoch 37 (train): dice=0.8813 | iou=0.7907 | loss=0.4879 | loss_bce=0.1999 | loss_dice=0.1187 | loss_iou=0.2093
# 37/100 * Epoch 37 (valid): dice=0.8927 | iou=0.8098 | loss=0.4415 | loss_bce=0.1799 | loss_dice=0.1073 | loss_iou=0.1902
# 38/100 * Epoch (train): 100% 41/41 [00:23<00:00,  1.78it/s, dice=0.949, iou=0.902, loss=0.217, loss_bce=0.085, loss_dice=0.051, loss_iou=0.098]
# 38/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.23it/s, dice=0.837, iou=0.720, loss=0.623, loss_bce=0.225, loss_dice=0.163, loss_iou=0.280]
# [2020-10-18 05:01:10,627]
# 38/100 * Epoch 38 (_base): lr=0.0003 | momentum=0.9000
# 38/100 * Epoch 38 (train): dice=0.9021 | iou=0.8244 | loss=0.4104 | loss_bce=0.1711 | loss_dice=0.0979 | loss_iou=0.1756
# 38/100 * Epoch 38 (valid): dice=0.9049 | iou=0.8295 | loss=0.3922 | loss_bce=0.1583 | loss_dice=0.0951 | loss_iou=0.1705
# 39/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.87it/s, dice=0.923, iou=0.857, loss=0.321, loss_bce=0.127, loss_dice=0.077, loss_iou=0.143]
# 39/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.17it/s, dice=0.839, iou=0.723, loss=0.622, loss_bce=0.231, loss_dice=0.161, loss_iou=0.277]
# [2020-10-18 05:01:35,357]
# 39/100 * Epoch 39 (_base): lr=0.0003 | momentum=0.9000
# 39/100 * Epoch 39 (train): dice=0.8989 | iou=0.8188 | loss=0.4187 | loss_bce=0.1705 | loss_dice=0.1011 | loss_iou=0.1812
# 39/100 * Epoch 39 (valid): dice=0.9006 | iou=0.8217 | loss=0.4082 | loss_bce=0.1630 | loss_dice=0.0994 | loss_iou=0.1783
# 40/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.85it/s, dice=0.906, iou=0.828, loss=0.429, loss_bce=0.203, loss_dice=0.094, loss_iou=0.172]
# 40/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.16it/s, dice=0.835, iou=0.717, loss=0.697, loss_bce=0.311, loss_dice=0.165, loss_iou=0.283]
# [2020-10-18 05:02:00,172]
# 40/100 * Epoch 40 (_base): lr=0.0003 | momentum=0.9000
# 40/100 * Epoch 40 (train): dice=0.9114 | iou=0.8385 | loss=0.3714 | loss_bce=0.1517 | loss_dice=0.0886 | loss_iou=0.1615
# 40/100 * Epoch 40 (valid): dice=0.8905 | iou=0.8061 | loss=0.4575 | loss_bce=0.1926 | loss_dice=0.1095 | loss_iou=0.1939
# 41/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.81it/s, dice=0.941, iou=0.888, loss=0.239, loss_bce=0.085, loss_dice=0.059, loss_iou=0.112]
# 41/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.17it/s, dice=0.851, iou=0.741, loss=0.574, loss_bce=0.209, loss_dice=0.149, loss_iou=0.259]
# [2020-10-18 05:02:25,720]
# 41/100 * Epoch 41 (_base): lr=0.0001 | momentum=0.9000
# 41/100 * Epoch 41 (train): dice=0.9065 | iou=0.8306 | loss=0.3927 | loss_bce=0.1622 | loss_dice=0.0935 | loss_iou=0.1694
# 41/100 * Epoch 41 (valid): dice=0.8977 | iou=0.8180 | loss=0.4411 | loss_bce=0.1960 | loss_dice=0.1023 | loss_iou=0.1820
# 42/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.84it/s, dice=0.893, iou=0.806, loss=0.507, loss_bce=0.257, loss_dice=0.107, loss_iou=0.194]
# 42/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.35it/s, dice=0.849, iou=0.738, loss=0.578, loss_bce=0.206, loss_dice=0.151, loss_iou=0.262]
# [2020-10-18 05:02:50,570]
# 42/100 * Epoch 42 (_base): lr=0.0001 | momentum=0.9000
# 42/100 * Epoch 42 (train): dice=0.9082 | iou=0.8332 | loss=0.3837 | loss_bce=0.1565 | loss_dice=0.0918 | loss_iou=0.1668
# 42/100 * Epoch 42 (valid): dice=0.9049 | iou=0.8289 | loss=0.3820 | loss_bce=0.1447 | loss_dice=0.0951 | loss_iou=0.1711
# 43/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.85it/s, dice=0.930, iou=0.870, loss=0.321, loss_bce=0.151, loss_dice=0.070, loss_iou=0.130]
# 43/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.05it/s, dice=0.831, iou=0.710, loss=0.612, loss_bce=0.191, loss_dice=0.169, loss_iou=0.290]
# [2020-10-18 05:03:15,386]
# 43/100 * Epoch 43 (_base): lr=0.0001 | momentum=0.9000
# 43/100 * Epoch 43 (train): dice=0.9063 | iou=0.8308 | loss=0.3880 | loss_bce=0.1563 | loss_dice=0.0937 | loss_iou=0.1692
# 43/100 * Epoch 43 (valid): dice=0.9027 | iou=0.8254 | loss=0.3873 | loss_bce=0.1442 | loss_dice=0.0973 | loss_iou=0.1746
# 44/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.82it/s, dice=0.905, iou=0.826, loss=0.375, loss_bce=0.133, loss_dice=0.095, loss_iou=0.174]
# 44/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.17it/s, dice=0.863, iou=0.759, loss=0.534, loss_bce=0.195, loss_dice=0.137, loss_iou=0.241]
# [2020-10-18 05:03:40,750]
# 44/100 * Epoch 44 (_base): lr=0.0001 | momentum=0.9000
# 44/100 * Epoch 44 (train): dice=0.9114 | iou=0.8390 | loss=0.3714 | loss_bce=0.1522 | loss_dice=0.0886 | loss_iou=0.1610
# 44/100 * Epoch 44 (valid): dice=0.9078 | iou=0.8337 | loss=0.3796 | loss_bce=0.1515 | loss_dice=0.0922 | loss_iou=0.1663
# 45/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.87it/s, dice=0.949, iou=0.902, loss=0.218, loss_bce=0.086, loss_dice=0.051, loss_iou=0.098]
# 45/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.12it/s, dice=0.837, iou=0.719, loss=0.657, loss_bce=0.267, loss_dice=0.163, loss_iou=0.281]
# [2020-10-18 05:04:05,460]
# 45/100 * Epoch 45 (_base): lr=0.0001 | momentum=0.9000
# 45/100 * Epoch 45 (train): dice=0.9021 | iou=0.8231 | loss=0.4156 | loss_bce=0.1760 | loss_dice=0.0979 | loss_iou=0.1769
# 45/100 * Epoch 45 (valid): dice=0.8965 | iou=0.8151 | loss=0.4240 | loss_bce=0.1694 | loss_dice=0.1035 | loss_iou=0.1849
# 46/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.86it/s, dice=0.857, iou=0.749, loss=0.632, loss_bce=0.297, loss_dice=0.143, loss_iou=0.251]
# 46/100 * Epoch (valid): 100% 10/10 [00:03<00:00,  3.19it/s, dice=0.847, iou=0.734, loss=0.571, loss_bce=0.190, loss_dice=0.153, loss_iou=0.266]
# [2020-10-18 05:04:30,905]
# 46/100 * Epoch 46 (_base): lr=0.0001 | momentum=0.9000
# 46/100 * Epoch 46 (train): dice=0.9089 | iou=0.8350 | loss=0.3849 | loss_bce=0.1610 | loss_dice=0.0911 | loss_iou=0.1650
# 46/100 * Epoch 46 (valid): dice=0.9073 | iou=0.8330 | loss=0.3793 | loss_bce=0.1496 | loss_dice=0.0927 | loss_iou=0.1670
# 47/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.87it/s, dice=0.843, iou=0.728, loss=0.758, loss_bce=0.411, loss_dice=0.157, loss_iou=0.272]
# 47/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.16it/s, dice=0.853, iou=0.744, loss=0.560, loss_bce=0.197, loss_dice=0.147, loss_iou=0.256]
# [2020-10-18 05:04:55,523]
# 47/100 * Epoch 47 (_base): lr=6.250e-05 | momentum=0.9000
# 47/100 * Epoch 47 (train): dice=0.9050 | iou=0.8285 | loss=0.3962 | loss_bce=0.1622 | loss_dice=0.0950 | loss_iou=0.1715
# 47/100 * Epoch 47 (valid): dice=0.9055 | iou=0.8301 | loss=0.3863 | loss_bce=0.1524 | loss_dice=0.0945 | loss_iou=0.1699
# 48/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.85it/s, dice=0.898, iou=0.815, loss=0.502, loss_bce=0.270, loss_dice=0.102, loss_iou=0.185]
# 48/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.18it/s, dice=0.839, iou=0.723, loss=0.638, loss_bce=0.249, loss_dice=0.161, loss_iou=0.277]
# [2020-10-18 05:05:20,371]
# 48/100 * Epoch 48 (_base): lr=6.250e-05 | momentum=0.9000
# 48/100 * Epoch 48 (train): dice=0.9008 | iou=0.8232 | loss=0.4091 | loss_bce=0.1663 | loss_dice=0.0992 | loss_iou=0.1768
# 48/100 * Epoch 48 (valid): dice=0.8958 | iou=0.8141 | loss=0.4425 | loss_bce=0.1905 | loss_dice=0.1042 | loss_iou=0.1859
# 49/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.84it/s, dice=0.896, iou=0.812, loss=0.357, loss_bce=0.081, loss_dice=0.104, loss_iou=0.188]
# 49/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.16it/s, dice=0.832, iou=0.712, loss=0.641, loss_bce=0.232, loss_dice=0.168, loss_iou=0.288]
# [2020-10-18 05:05:45,312]
# 49/100 * Epoch 49 (_base): lr=6.250e-05 | momentum=0.9000
# 49/100 * Epoch 49 (train): dice=0.9044 | iou=0.8281 | loss=0.3952 | loss_bce=0.1596 | loss_dice=0.0956 | loss_iou=0.1719
# 49/100 * Epoch 49 (valid): dice=0.9028 | iou=0.8259 | loss=0.3981 | loss_bce=0.1585 | loss_dice=0.0972 | loss_iou=0.1741
# 50/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.85it/s, dice=0.889, iou=0.801, loss=0.410, loss_bce=0.126, loss_dice=0.111, loss_iou=0.199]
# 50/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  3.88it/s, dice=0.855, iou=0.747, loss=0.541, loss_bce=0.179, loss_dice=0.145, loss_iou=0.253]
# [2020-10-18 05:06:10,318]
# 50/100 * Epoch 50 (_base): lr=3.125e-05 | momentum=0.9000
# 50/100 * Epoch 50 (train): dice=0.9075 | iou=0.8327 | loss=0.3793 | loss_bce=0.1493 | loss_dice=0.0925 | loss_iou=0.1673
# 50/100 * Epoch 50 (valid): dice=0.9060 | iou=0.8305 | loss=0.3836 | loss_bce=0.1502 | loss_dice=0.0940 | loss_iou=0.1695
# 51/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.81it/s, dice=0.934, iou=0.877, loss=0.282, loss_bce=0.117, loss_dice=0.066, loss_iou=0.123]
# 51/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.16it/s, dice=0.851, iou=0.740, loss=0.554, loss_bce=0.182, loss_dice=0.149, loss_iou=0.260]
# [2020-10-18 05:06:36,232]
# 51/100 * Epoch 51 (_base): lr=3.125e-05 | momentum=0.9000
# 51/100 * Epoch 51 (train): dice=0.9083 | iou=0.8340 | loss=0.3810 | loss_bce=0.1541 | loss_dice=0.0917 | loss_iou=0.1660
# 51/100 * Epoch 51 (valid): dice=0.9053 | iou=0.8303 | loss=0.3840 | loss_bce=0.1494 | loss_dice=0.0947 | loss_iou=0.1697
# 52/100 * Epoch (train): 100% 41/41 [00:23<00:00,  1.78it/s, dice=0.897, iou=0.814, loss=0.411, loss_bce=0.152, loss_dice=0.103, loss_iou=0.186]
# 52/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.07it/s, dice=0.826, iou=0.703, loss=0.669, loss_bce=0.247, loss_dice=0.174, loss_iou=0.297]
# [2020-10-18 05:07:01,983]
# 52/100 * Epoch 52 (_base): lr=3.125e-05 | momentum=0.9000
# 52/100 * Epoch 52 (train): dice=0.9092 | iou=0.8359 | loss=0.3856 | loss_bce=0.1635 | loss_dice=0.0908 | loss_iou=0.1641
# 52/100 * Epoch 52 (valid): dice=0.8979 | iou=0.8180 | loss=0.4251 | loss_bce=0.1763 | loss_dice=0.1021 | loss_iou=0.1820
# 53/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.84it/s, dice=0.942, iou=0.890, loss=0.254, loss_bce=0.108, loss_dice=0.058, loss_iou=0.110]
# 53/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.16it/s, dice=0.852, iou=0.742, loss=0.649, loss_bce=0.304, loss_dice=0.148, loss_iou=0.258]
# [2020-10-18 05:07:26,898]
# 53/100 * Epoch 53 (_base): lr=1.563e-05 | momentum=0.9000
# 53/100 * Epoch 53 (train): dice=0.9123 | iou=0.8404 | loss=0.3622 | loss_bce=0.1436 | loss_dice=0.0877 | loss_iou=0.1596
# 53/100 * Epoch 53 (valid): dice=0.9048 | iou=0.8296 | loss=0.3948 | loss_bce=0.1614 | loss_dice=0.0952 | loss_iou=0.1704
# 54/100 * Epoch (train): 100% 41/41 [00:23<00:00,  1.77it/s, dice=0.938, iou=0.883, loss=0.280, loss_bce=0.125, loss_dice=0.062, loss_iou=0.117]
# 54/100 * Epoch (valid): 100% 10/10 [00:03<00:00,  2.94it/s, dice=0.850, iou=0.740, loss=0.560, loss_bce=0.188, loss_dice=0.150, loss_iou=0.260]
# [2020-10-18 05:07:53,707]
# 54/100 * Epoch 54 (_base): lr=1.563e-05 | momentum=0.9000
# 54/100 * Epoch 54 (train): dice=0.9088 | iou=0.8345 | loss=0.3866 | loss_bce=0.1624 | loss_dice=0.0912 | loss_iou=0.1655
# 54/100 * Epoch 54 (valid): dice=0.9046 | iou=0.8292 | loss=0.3866 | loss_bce=0.1505 | loss_dice=0.0954 | loss_iou=0.1708
# 55/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.86it/s, dice=0.852, iou=0.742, loss=0.622, loss_bce=0.270, loss_dice=0.148, loss_iou=0.258]
# 55/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.26it/s, dice=0.869, iou=0.768, loss=0.533, loss_bce=0.212, loss_dice=0.131, loss_iou=0.232]
# [2020-10-18 05:08:18,478]
# 55/100 * Epoch 55 (_base): lr=1.563e-05 | momentum=0.9000
# 55/100 * Epoch 55 (train): dice=0.9100 | iou=0.8362 | loss=0.3731 | loss_bce=0.1491 | loss_dice=0.0900 | loss_iou=0.1638
# 55/100 * Epoch 55 (valid): dice=0.9048 | iou=0.8283 | loss=0.4043 | loss_bce=0.1718 | loss_dice=0.0952 | loss_iou=0.1717
# 56/100 * Epoch (train): 100% 41/41 [00:23<00:00,  1.75it/s, dice=0.950, iou=0.904, loss=0.226, loss_bce=0.100, loss_dice=0.050, loss_iou=0.096]
# 56/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.36it/s, dice=0.853, iou=0.744, loss=0.551, loss_bce=0.185, loss_dice=0.147, loss_iou=0.256]
# [2020-10-18 05:08:44,526]
# 56/100 * Epoch 56 (_base): lr=7.813e-06 | momentum=0.9000
# 56/100 * Epoch 56 (train): dice=0.9090 | iou=0.8346 | loss=0.3767 | loss_bce=0.1504 | loss_dice=0.0910 | loss_iou=0.1654
# 56/100 * Epoch 56 (valid): dice=0.9076 | iou=0.8326 | loss=0.3677 | loss_bce=0.1348 | loss_dice=0.0924 | loss_iou=0.1674
# 57/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.79it/s, dice=0.940, iou=0.887, loss=0.248, loss_bce=0.094, loss_dice=0.060, loss_iou=0.113]
# 57/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.20it/s, dice=0.851, iou=0.740, loss=0.559, loss_bce=0.187, loss_dice=0.149, loss_iou=0.260]
# [2020-10-18 05:09:10,153]
# 57/100 * Epoch 57 (_base): lr=7.813e-06 | momentum=0.9000
# 57/100 * Epoch 57 (train): dice=0.9128 | iou=0.8411 | loss=0.3684 | loss_bce=0.1528 | loss_dice=0.0872 | loss_iou=0.1589
# 57/100 * Epoch 57 (valid): dice=0.9091 | iou=0.8358 | loss=0.3683 | loss_bce=0.1415 | loss_dice=0.0909 | loss_iou=0.1642
# 58/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.81it/s, dice=0.908, iou=0.831, loss=0.328, loss_bce=0.083, loss_dice=0.092, loss_iou=0.169]
# 58/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.26it/s, dice=0.876, iou=0.780, loss=0.501, loss_bce=0.197, loss_dice=0.124, loss_iou=0.220]
# [2020-10-18 05:09:35,810]
# 58/100 * Epoch 58 (_base): lr=7.813e-06 | momentum=0.9000
# 58/100 * Epoch 58 (train): dice=0.9116 | iou=0.8392 | loss=0.3750 | loss_bce=0.1573 | loss_dice=0.0884 | loss_iou=0.1608
# 58/100 * Epoch 58 (valid): dice=0.9093 | iou=0.8359 | loss=0.3721 | loss_bce=0.1466 | loss_dice=0.0907 | loss_iou=0.1641
# 59/100 * Epoch (train): 100% 41/41 [00:23<00:00,  1.74it/s, dice=0.939, iou=0.884, loss=0.261, loss_bce=0.106, loss_dice=0.061, loss_iou=0.116]
# 59/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.21it/s, dice=0.871, iou=0.771, loss=0.514, loss_bce=0.196, loss_dice=0.129, loss_iou=0.229]
# [2020-10-18 05:10:02,291]
# 59/100 * Epoch 59 (_base): lr=7.813e-06 | momentum=0.9000
# 59/100 * Epoch 59 (train): dice=0.9140 | iou=0.8433 | loss=0.3608 | loss_bce=0.1476 | loss_dice=0.0860 | loss_iou=0.1567
# 59/100 * Epoch 59 (valid): dice=0.9141 | iou=0.8438 | loss=0.3576 | loss_bce=0.1444 | loss_dice=0.0859 | loss_iou=0.1562
# 60/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.83it/s, dice=0.923, iou=0.857, loss=0.318, loss_bce=0.121, loss_dice=0.077, loss_iou=0.143]
# 60/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.20it/s, dice=0.851, iou=0.741, loss=0.569, loss_bce=0.202, loss_dice=0.149, loss_iou=0.259]
# [2020-10-18 05:10:27,380]
# 60/100 * Epoch 60 (_base): lr=7.813e-06 | momentum=0.9000
# 60/100 * Epoch 60 (train): dice=0.9162 | iou=0.8467 | loss=0.3490 | loss_bce=0.1399 | loss_dice=0.0838 | loss_iou=0.1533
# 60/100 * Epoch 60 (valid): dice=0.9062 | iou=0.8315 | loss=0.3846 | loss_bce=0.1527 | loss_dice=0.0938 | loss_iou=0.1685
# 61/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.84it/s, dice=0.901, iou=0.820, loss=0.473, loss_bce=0.243, loss_dice=0.099, loss_iou=0.180]
# 61/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  3.99it/s, dice=0.868, iou=0.767, loss=0.511, loss_bce=0.183, loss_dice=0.132, loss_iou=0.233]
# [2020-10-18 05:10:52,431]
# 61/100 * Epoch 61 (_base): lr=7.813e-06 | momentum=0.9000
# 61/100 * Epoch 61 (train): dice=0.9123 | iou=0.8407 | loss=0.3802 | loss_bce=0.1664 | loss_dice=0.0877 | loss_iou=0.1593
# 61/100 * Epoch 61 (valid): dice=0.9114 | iou=0.8392 | loss=0.3654 | loss_bce=0.1450 | loss_dice=0.0886 | loss_iou=0.1608
# 62/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.83it/s, dice=0.924, iou=0.858, loss=0.334, loss_bce=0.145, loss_dice=0.076, loss_iou=0.142]
# 62/100 * Epoch (valid): 100% 10/10 [00:03<00:00,  3.11it/s, dice=0.856, iou=0.748, loss=0.557, loss_bce=0.201, loss_dice=0.144, loss_iou=0.252]
# [2020-10-18 05:11:18,361]
# 62/100 * Epoch 62 (_base): lr=3.906e-06 | momentum=0.9000
# 62/100 * Epoch 62 (train): dice=0.9144 | iou=0.8440 | loss=0.3531 | loss_bce=0.1394 | loss_dice=0.0856 | loss_iou=0.1560
# 62/100 * Epoch 62 (valid): dice=0.9047 | iou=0.8284 | loss=0.3997 | loss_bce=0.1659 | loss_dice=0.0953 | loss_iou=0.1716
# 63/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.86it/s, dice=0.866, iou=0.763, loss=0.678, loss_bce=0.385, loss_dice=0.134, loss_iou=0.237]
# 63/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.16it/s, dice=0.875, iou=0.777, loss=0.488, loss_bce=0.175, loss_dice=0.125, loss_iou=0.223]
# [2020-10-18 05:11:43,087]
# 63/100 * Epoch 63 (_base): lr=3.906e-06 | momentum=0.9000
# 63/100 * Epoch 63 (train): dice=0.9118 | iou=0.8394 | loss=0.3805 | loss_bce=0.1648 | loss_dice=0.0882 | loss_iou=0.1606
# 63/100 * Epoch 63 (valid): dice=0.9059 | iou=0.8311 | loss=0.3926 | loss_bce=0.1619 | loss_dice=0.0941 | loss_iou=0.1689
# 64/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.84it/s, dice=0.912, iou=0.838, loss=0.313, loss_bce=0.079, loss_dice=0.088, loss_iou=0.162]
# 64/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.10it/s, dice=0.849, iou=0.738, loss=0.632, loss_bce=0.273, loss_dice=0.151, loss_iou=0.262]
# [2020-10-18 05:12:08,012]
# 64/100 * Epoch 64 (_base): lr=3.906e-06 | momentum=0.9000
# 64/100 * Epoch 64 (train): dice=0.9158 | iou=0.8462 | loss=0.3507 | loss_bce=0.1409 | loss_dice=0.0842 | loss_iou=0.1538
# 64/100 * Epoch 64 (valid): dice=0.9009 | iou=0.8223 | loss=0.4091 | loss_bce=0.1654 | loss_dice=0.0991 | loss_iou=0.1777
# 65/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.86it/s, dice=0.869, iou=0.768, loss=0.527, loss_bce=0.204, loss_dice=0.131, loss_iou=0.232]
# 65/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.11it/s, dice=0.855, iou=0.747, loss=0.553, loss_bce=0.195, loss_dice=0.145, loss_iou=0.253]
# [2020-10-18 05:12:32,764]
# 65/100 * Epoch 65 (_base): lr=1.953e-06 | momentum=0.9000
# 65/100 * Epoch 65 (train): dice=0.9117 | iou=0.8395 | loss=0.3661 | loss_bce=0.1465 | loss_dice=0.0883 | loss_iou=0.1605
# 65/100 * Epoch 65 (valid): dice=0.9095 | iou=0.8357 | loss=0.3618 | loss_bce=0.1338 | loss_dice=0.0905 | loss_iou=0.1643
# 66/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.82it/s, dice=0.917, iou=0.846, loss=0.358, loss_bce=0.151, loss_dice=0.083, loss_iou=0.154]
# 66/100 * Epoch (valid): 100% 10/10 [00:03<00:00,  3.08it/s, dice=0.820, iou=0.695, loss=0.720, loss_bce=0.294, loss_dice=0.180, loss_iou=0.305]
# [2020-10-18 05:12:58,758]
# 66/100 * Epoch 66 (_base): lr=1.953e-06 | momentum=0.9000
# 66/100 * Epoch 66 (train): dice=0.9135 | iou=0.8420 | loss=0.3648 | loss_bce=0.1503 | loss_dice=0.0865 | loss_iou=0.1580
# 66/100 * Epoch 66 (valid): dice=0.8996 | iou=0.8209 | loss=0.4084 | loss_bce=0.1611 | loss_dice=0.1004 | loss_iou=0.1791
# 67/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.79it/s, dice=0.875, iou=0.778, loss=0.609, loss_bce=0.328, loss_dice=0.125, loss_iou=0.222]
# 67/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.14it/s, dice=0.852, iou=0.742, loss=0.565, loss_bce=0.199, loss_dice=0.148, loss_iou=0.258]
# [2020-10-18 05:13:24,295]
# 67/100 * Epoch 67 (_base): lr=1.953e-06 | momentum=0.9000
# 67/100 * Epoch 67 (train): dice=0.9106 | iou=0.8380 | loss=0.3725 | loss_bce=0.1515 | loss_dice=0.0894 | loss_iou=0.1620
# 67/100 * Epoch 67 (valid): dice=0.9081 | iou=0.8341 | loss=0.3788 | loss_bce=0.1512 | loss_dice=0.0919 | loss_iou=0.1659
# 68/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.84it/s, dice=0.924, iou=0.859, loss=0.341, loss_bce=0.157, loss_dice=0.076, loss_iou=0.141]
# 68/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.13it/s, dice=0.854, iou=0.746, loss=0.538, loss_bce=0.172, loss_dice=0.146, loss_iou=0.254]
# [2020-10-18 05:13:49,238]
# 68/100 * Epoch 68 (_base): lr=9.766e-07 | momentum=0.9000
# 68/100 * Epoch 68 (train): dice=0.9147 | iou=0.8440 | loss=0.3536 | loss_bce=0.1404 | loss_dice=0.0853 | loss_iou=0.1560
# 68/100 * Epoch 68 (valid): dice=0.9096 | iou=0.8367 | loss=0.3689 | loss_bce=0.1439 | loss_dice=0.0904 | loss_iou=0.1633
# 69/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.87it/s, dice=0.846, iou=0.734, loss=0.623, loss_bce=0.253, loss_dice=0.154, loss_iou=0.266]
# 69/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.23it/s, dice=0.851, iou=0.741, loss=0.570, loss_bce=0.203, loss_dice=0.149, loss_iou=0.259]
# [2020-10-18 05:14:13,765]
# 69/100 * Epoch 69 (_base): lr=9.766e-07 | momentum=0.9000
# 69/100 * Epoch 69 (train): dice=0.9140 | iou=0.8432 | loss=0.3571 | loss_bce=0.1429 | loss_dice=0.0860 | loss_iou=0.1568
# 69/100 * Epoch 69 (valid): dice=0.9037 | iou=0.8266 | loss=0.3999 | loss_bce=0.1628 | loss_dice=0.0963 | loss_iou=0.1734
# 70/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.84it/s, dice=0.943, iou=0.891, loss=0.227, loss_bce=0.077, loss_dice=0.057, loss_iou=0.109]
# 70/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.29it/s, dice=0.870, iou=0.770, loss=0.506, loss_bce=0.182, loss_dice=0.130, loss_iou=0.230]
# [2020-10-18 05:14:38,559]
# 70/100 * Epoch 70 (_base): lr=9.766e-07 | momentum=0.9000
# 70/100 * Epoch 70 (train): dice=0.9159 | iou=0.8461 | loss=0.3527 | loss_bce=0.1433 | loss_dice=0.0841 | loss_iou=0.1539
# 70/100 * Epoch 70 (valid): dice=0.9068 | iou=0.8320 | loss=0.3859 | loss_bce=0.1558 | loss_dice=0.0932 | loss_iou=0.1680
# 71/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.87it/s, dice=0.941, iou=0.889, loss=0.240, loss_bce=0.087, loss_dice=0.059, loss_iou=0.111]
# 71/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.23it/s, dice=0.859, iou=0.752, loss=0.545, loss_bce=0.195, loss_dice=0.141, loss_iou=0.248]
# [2020-10-18 05:15:03,063]
# 71/100 * Epoch 71 (_base): lr=4.883e-07 | momentum=0.9000
# 71/100 * Epoch 71 (train): dice=0.9137 | iou=0.8428 | loss=0.3596 | loss_bce=0.1450 | loss_dice=0.0863 | loss_iou=0.1572
# 71/100 * Epoch 71 (valid): dice=0.9087 | iou=0.8350 | loss=0.3788 | loss_bce=0.1530 | loss_dice=0.0913 | loss_iou=0.1650
# 72/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.86it/s, dice=0.943, iou=0.892, loss=0.242, loss_bce=0.096, loss_dice=0.057, loss_iou=0.108]
# 72/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.26it/s, dice=0.842, iou=0.727, loss=0.637, loss_bce=0.257, loss_dice=0.158, loss_iou=0.273]
# [2020-10-18 05:15:27,674]
# 72/100 * Epoch 72 (_base): lr=4.883e-07 | momentum=0.9000
# 72/100 * Epoch 72 (train): dice=0.9127 | iou=0.8407 | loss=0.3616 | loss_bce=0.1438 | loss_dice=0.0873 | loss_iou=0.1593
# 72/100 * Epoch 72 (valid): dice=0.8993 | iou=0.8195 | loss=0.4201 | loss_bce=0.1735 | loss_dice=0.1007 | loss_iou=0.1805
# 73/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.79it/s, dice=0.859, iou=0.753, loss=0.522, loss_bce=0.169, loss_dice=0.141, loss_iou=0.247]
# 73/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.16it/s, dice=0.840, iou=0.725, loss=0.622, loss_bce=0.233, loss_dice=0.160, loss_iou=0.275]
# [2020-10-18 05:15:53,194]
# 73/100 * Epoch 73 (_base): lr=4.883e-07 | momentum=0.9000
# 73/100 * Epoch 73 (train): dice=0.9134 | iou=0.8422 | loss=0.3645 | loss_bce=0.1501 | loss_dice=0.0866 | loss_iou=0.1578
# 73/100 * Epoch 73 (valid): dice=0.9047 | iou=0.8298 | loss=0.3887 | loss_bce=0.1540 | loss_dice=0.0953 | loss_iou=0.1702
# 74/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.86it/s, dice=0.926, iou=0.862, loss=0.321, loss_bce=0.135, loss_dice=0.074, loss_iou=0.138]
# 74/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.17it/s, dice=0.880, iou=0.786, loss=0.482, loss_bce=0.185, loss_dice=0.120, loss_iou=0.214]
# [2020-10-18 05:16:17,886]
# 74/100 * Epoch 74 (_base): lr=2.441e-07 | momentum=0.9000
# 74/100 * Epoch 74 (train): dice=0.9151 | iou=0.8448 | loss=0.3501 | loss_bce=0.1375 | loss_dice=0.0849 | loss_iou=0.1552
# 74/100 * Epoch 74 (valid): dice=0.9074 | iou=0.8327 | loss=0.3804 | loss_bce=0.1506 | loss_dice=0.0926 | loss_iou=0.1673
# 75/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.85it/s, dice=0.853, iou=0.744, loss=0.524, loss_bce=0.151, loss_dice=0.147, loss_iou=0.256]
# 75/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.14it/s, dice=0.855, iou=0.747, loss=0.552, loss_bce=0.192, loss_dice=0.145, loss_iou=0.253]
# [2020-10-18 05:16:42,752]
# 75/100 * Epoch 75 (_base): lr=2.441e-07 | momentum=0.9000
# 75/100 * Epoch 75 (train): dice=0.9123 | iou=0.8407 | loss=0.3665 | loss_bce=0.1494 | loss_dice=0.0877 | loss_iou=0.1593
# 75/100 * Epoch 75 (valid): dice=0.8957 | iou=0.8133 | loss=0.4321 | loss_bce=0.1764 | loss_dice=0.1043 | loss_iou=0.1867
# 76/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.86it/s, dice=0.921, iou=0.853, loss=0.312, loss_bce=0.107, loss_dice=0.079, loss_iou=0.147]
# 76/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.20it/s, dice=0.835, iou=0.716, loss=0.637, loss_bce=0.236, loss_dice=0.165, loss_iou=0.284]
# [2020-10-18 05:17:07,422]
# 76/100 * Epoch 76 (_base): lr=2.441e-07 | momentum=0.9000
# 76/100 * Epoch 76 (train): dice=0.9105 | iou=0.8375 | loss=0.3749 | loss_bce=0.1537 | loss_dice=0.0895 | loss_iou=0.1625
# 76/100 * Epoch 76 (valid): dice=0.9002 | iou=0.8215 | loss=0.4112 | loss_bce=0.1662 | loss_dice=0.0998 | loss_iou=0.1785
# 77/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.81it/s, dice=0.936, iou=0.881, loss=0.270, loss_bce=0.109, loss_dice=0.064, loss_iou=0.119]
# 77/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.05it/s, dice=0.851, iou=0.740, loss=0.573, loss_bce=0.205, loss_dice=0.149, loss_iou=0.260]
# [2020-10-18 05:17:32,784]
# 77/100 * Epoch 77 (_base): lr=1.221e-07 | momentum=0.9000
# 77/100 * Epoch 77 (train): dice=0.9116 | iou=0.8402 | loss=0.3682 | loss_bce=0.1500 | loss_dice=0.0884 | loss_iou=0.1598
# 77/100 * Epoch 77 (valid): dice=0.9079 | iou=0.8336 | loss=0.3799 | loss_bce=0.1517 | loss_dice=0.0921 | loss_iou=0.1664
# 78/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.83it/s, dice=0.911, iou=0.836, loss=0.340, loss_bce=0.109, loss_dice=0.089, loss_iou=0.164]
# 78/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.24it/s, dice=0.839, iou=0.723, loss=0.645, loss_bce=0.259, loss_dice=0.161, loss_iou=0.277]
# [2020-10-18 05:17:57,741]
# 78/100 * Epoch 78 (_base): lr=1.221e-07 | momentum=0.9000
# 78/100 * Epoch 78 (train): dice=0.9172 | iou=0.8481 | loss=0.3436 | loss_bce=0.1361 | loss_dice=0.0828 | loss_iou=0.1519
# 78/100 * Epoch 78 (valid): dice=0.9052 | iou=0.8298 | loss=0.3905 | loss_bce=0.1569 | loss_dice=0.0948 | loss_iou=0.1702
# 79/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.88it/s, dice=0.811, iou=0.683, loss=0.687, loss_bce=0.227, loss_dice=0.189, loss_iou=0.317]
# 79/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.29it/s, dice=0.845, iou=0.731, loss=0.616, loss_bce=0.240, loss_dice=0.155, loss_iou=0.269]
# [2020-10-18 05:18:22,134]
# 79/100 * Epoch 79 (_base): lr=1.221e-07 | momentum=0.9000
# 79/100 * Epoch 79 (train): dice=0.9115 | iou=0.8389 | loss=0.3726 | loss_bce=0.1537 | loss_dice=0.0885 | loss_iou=0.1611
# 79/100 * Epoch 79 (valid): dice=0.8993 | iou=0.8206 | loss=0.4274 | loss_bce=0.1841 | loss_dice=0.1007 | loss_iou=0.1794
# 80/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.87it/s, dice=0.853, iou=0.744, loss=0.527, loss_bce=0.154, loss_dice=0.147, loss_iou=0.256]
# 80/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.02it/s, dice=0.861, iou=0.756, loss=0.533, loss_bce=0.189, loss_dice=0.139, loss_iou=0.244]
# [2020-10-18 05:18:46,817]
# 80/100 * Epoch 80 (_base): lr=6.104e-08 | momentum=0.9000
# 80/100 * Epoch 80 (train): dice=0.9127 | iou=0.8407 | loss=0.3625 | loss_bce=0.1449 | loss_dice=0.0873 | loss_iou=0.1593
# 80/100 * Epoch 80 (valid): dice=0.9118 | iou=0.8400 | loss=0.3563 | loss_bce=0.1352 | loss_dice=0.0882 | loss_iou=0.1600
# 81/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.88it/s, dice=0.884, iou=0.792, loss=0.436, loss_bce=0.140, loss_dice=0.116, loss_iou=0.208]
# 81/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.27it/s, dice=0.841, iou=0.725, loss=0.624, loss_bce=0.237, loss_dice=0.159, loss_iou=0.275]
# [2020-10-18 05:19:11,477]
# 81/100 * Epoch 81 (_base): lr=6.104e-08 | momentum=0.9000
# 81/100 * Epoch 81 (train): dice=0.9154 | iou=0.8455 | loss=0.3458 | loss_bce=0.1333 | loss_dice=0.0846 | loss_iou=0.1545
# 81/100 * Epoch 81 (valid): dice=0.8978 | iou=0.8181 | loss=0.4147 | loss_bce=0.1633 | loss_dice=0.1022 | loss_iou=0.1819
# 82/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.90it/s, dice=0.938, iou=0.884, loss=0.249, loss_bce=0.089, loss_dice=0.062, loss_iou=0.116]
# 82/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.32it/s, dice=0.866, iou=0.764, loss=0.525, loss_bce=0.194, loss_dice=0.134, loss_iou=0.236]
# [2020-10-18 05:19:35,646]
# 82/100 * Epoch 82 (_base): lr=6.104e-08 | momentum=0.9000
# 82/100 * Epoch 82 (train): dice=0.9130 | iou=0.8417 | loss=0.3660 | loss_bce=0.1509 | loss_dice=0.0870 | loss_iou=0.1583
# 82/100 * Epoch 82 (valid): dice=0.9035 | iou=0.8261 | loss=0.4071 | loss_bce=0.1710 | loss_dice=0.0965 | loss_iou=0.1739
# 83/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.90it/s, dice=0.882, iou=0.789, loss=0.536, loss_bce=0.258, loss_dice=0.118, loss_iou=0.211]
# 83/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.36it/s, dice=0.857, iou=0.750, loss=0.555, loss_bce=0.203, loss_dice=0.143, loss_iou=0.250]
# [2020-10-18 05:19:59,720]
# 83/100 * Epoch 83 (_base): lr=3.052e-08 | momentum=0.9000
# 83/100 * Epoch 83 (train): dice=0.9137 | iou=0.8429 | loss=0.3570 | loss_bce=0.1420 | loss_dice=0.0863 | loss_iou=0.1571
# 83/100 * Epoch 83 (valid): dice=0.9094 | iou=0.8362 | loss=0.3763 | loss_bce=0.1523 | loss_dice=0.0906 | loss_iou=0.1638
# 84/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.90it/s, dice=0.903, iou=0.823, loss=0.357, loss_bce=0.103, loss_dice=0.097, loss_iou=0.177]
# 84/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.42it/s, dice=0.855, iou=0.747, loss=0.558, loss_bce=0.200, loss_dice=0.145, loss_iou=0.253]
# [2020-10-18 05:20:23,775]
# 84/100 * Epoch 84 (_base): lr=3.052e-08 | momentum=0.9000
# 84/100 * Epoch 84 (train): dice=0.9125 | iou=0.8416 | loss=0.3672 | loss_bce=0.1516 | loss_dice=0.0875 | loss_iou=0.1584
# 84/100 * Epoch 84 (valid): dice=0.9104 | iou=0.8378 | loss=0.3716 | loss_bce=0.1498 | loss_dice=0.0896 | loss_iou=0.1622
# 85/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.89it/s, dice=0.936, iou=0.880, loss=0.257, loss_bce=0.092, loss_dice=0.064, loss_iou=0.120]
# 85/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.33it/s, dice=0.845, iou=0.732, loss=0.575, loss_bce=0.190, loss_dice=0.155, loss_iou=0.268]
# [2020-10-18 05:20:47,977]
# 85/100 * Epoch 85 (_base): lr=3.052e-08 | momentum=0.9000
# 85/100 * Epoch 85 (train): dice=0.9145 | iou=0.8437 | loss=0.3597 | loss_bce=0.1475 | loss_dice=0.0855 | loss_iou=0.1563
# 85/100 * Epoch 85 (valid): dice=0.9027 | iou=0.8257 | loss=0.3924 | loss_bce=0.1510 | loss_dice=0.0973 | loss_iou=0.1743
# 86/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.85it/s, dice=0.843, iou=0.728, loss=0.583, loss_bce=0.192, loss_dice=0.157, loss_iou=0.272]
# 86/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.18it/s, dice=0.859, iou=0.752, loss=0.590, loss_bce=0.252, loss_dice=0.141, loss_iou=0.248]
# [2020-10-18 05:21:12,775]
# 86/100 * Epoch 86 (_base): lr=1.526e-08 | momentum=0.9000
# 86/100 * Epoch 86 (train): dice=0.9052 | iou=0.8291 | loss=0.3972 | loss_bce=0.1644 | loss_dice=0.0948 | loss_iou=0.1709
# 86/100 * Epoch 86 (valid): dice=0.9087 | iou=0.8349 | loss=0.3816 | loss_bce=0.1565 | loss_dice=0.0913 | loss_iou=0.1651
# 87/100 * Epoch (train): 100% 41/41 [00:23<00:00,  1.78it/s, dice=0.906, iou=0.828, loss=0.377, loss_bce=0.138, loss_dice=0.094, loss_iou=0.172]
# 87/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.21it/s, dice=0.832, iou=0.712, loss=0.653, loss_bce=0.246, loss_dice=0.168, loss_iou=0.288]
# [2020-10-18 05:21:38,388]
# 87/100 * Epoch 87 (_base): lr=1.526e-08 | momentum=0.9000
# 87/100 * Epoch 87 (train): dice=0.9167 | iou=0.8476 | loss=0.3498 | loss_bce=0.1426 | loss_dice=0.0833 | loss_iou=0.1524
# 87/100 * Epoch 87 (valid): dice=0.9048 | iou=0.8292 | loss=0.3923 | loss_bce=0.1577 | loss_dice=0.0952 | loss_iou=0.1708
# 88/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.87it/s, dice=0.944, iou=0.894, loss=0.245, loss_bce=0.103, loss_dice=0.056, loss_iou=0.106]
# 88/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.34it/s, dice=0.857, iou=0.750, loss=0.548, loss_bce=0.195, loss_dice=0.143, loss_iou=0.250]
# [2020-10-18 05:22:02,895]
# 88/100 * Epoch 88 (_base): lr=1.526e-08 | momentum=0.9000
# 88/100 * Epoch 88 (train): dice=0.9145 | iou=0.8447 | loss=0.3502 | loss_bce=0.1368 | loss_dice=0.0855 | loss_iou=0.1553
# 88/100 * Epoch 88 (valid): dice=0.9132 | iou=0.8418 | loss=0.3473 | loss_bce=0.1278 | loss_dice=0.0868 | loss_iou=0.1582
# 89/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.88it/s, dice=0.849, iou=0.738, loss=0.594, loss_bce=0.226, loss_dice=0.151, loss_iou=0.262]
# 89/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.39it/s, dice=0.862, iou=0.758, loss=0.532, loss_bce=0.190, loss_dice=0.138, loss_iou=0.242]
# [2020-10-18 05:22:27,245]
# 89/100 * Epoch 89 (_base): lr=1.526e-08 | momentum=0.9000
# 89/100 * Epoch 89 (train): dice=0.9139 | iou=0.8429 | loss=0.3640 | loss_bce=0.1510 | loss_dice=0.0861 | loss_iou=0.1571
# 89/100 * Epoch 89 (valid): dice=0.9088 | iou=0.8349 | loss=0.3806 | loss_bce=0.1554 | loss_dice=0.0912 | loss_iou=0.1651
# 90/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.85it/s, dice=0.906, iou=0.828, loss=0.359, loss_bce=0.117, loss_dice=0.094, loss_iou=0.172]
# 90/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.21it/s, dice=0.844, iou=0.730, loss=0.619, loss_bce=0.241, loss_dice=0.156, loss_iou=0.270]
# [2020-10-18 05:22:51,997]
# 90/100 * Epoch 90 (_base): lr=1.526e-08 | momentum=0.9000
# 90/100 * Epoch 90 (train): dice=0.9112 | iou=0.8391 | loss=0.3688 | loss_bce=0.1489 | loss_dice=0.0888 | loss_iou=0.1609
# 90/100 * Epoch 90 (valid): dice=0.9041 | iou=0.8278 | loss=0.3986 | loss_bce=0.1631 | loss_dice=0.0959 | loss_iou=0.1722
# 91/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.86it/s, dice=0.919, iou=0.850, loss=0.350, loss_bce=0.149, loss_dice=0.081, loss_iou=0.150]
# 91/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.33it/s, dice=0.851, iou=0.740, loss=0.569, loss_bce=0.200, loss_dice=0.149, loss_iou=0.260]
# [2020-10-18 05:23:16,618]
# 91/100 * Epoch 91 (_base): lr=1.526e-08 | momentum=0.9000
# 91/100 * Epoch 91 (train): dice=0.9171 | iou=0.8483 | loss=0.3491 | loss_bce=0.1431 | loss_dice=0.0829 | loss_iou=0.1517
# 91/100 * Epoch 91 (valid): dice=0.9025 | iou=0.8258 | loss=0.4024 | loss_bce=0.1633 | loss_dice=0.0975 | loss_iou=0.1742
# 92/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.83it/s, dice=0.849, iou=0.737, loss=0.570, loss_bce=0.195, loss_dice=0.151, loss_iou=0.263]
# 92/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.26it/s, dice=0.861, iou=0.756, loss=0.532, loss_bce=0.186, loss_dice=0.139, loss_iou=0.244]
# [2020-10-18 05:23:41,547]
# 92/100 * Epoch 92 (_base): lr=1.526e-08 | momentum=0.9000
# 92/100 * Epoch 92 (train): dice=0.9134 | iou=0.8422 | loss=0.3640 | loss_bce=0.1495 | loss_dice=0.0866 | loss_iou=0.1578
# 92/100 * Epoch 92 (valid): dice=0.9091 | iou=0.8357 | loss=0.3713 | loss_bce=0.1451 | loss_dice=0.0909 | loss_iou=0.1643
# 93/100 * Epoch (train): 100% 41/41 [00:24<00:00,  1.67it/s, dice=0.897, iou=0.813, loss=0.457, loss_bce=0.209, loss_dice=0.103, loss_iou=0.187]
# 93/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  3.73it/s, dice=0.853, iou=0.743, loss=0.550, loss_bce=0.183, loss_dice=0.147, loss_iou=0.257]
# [2020-10-18 05:24:09,103]
# 93/100 * Epoch 93 (_base): lr=1.526e-08 | momentum=0.9000
# 93/100 * Epoch 93 (train): dice=0.9142 | iou=0.8432 | loss=0.3614 | loss_bce=0.1484 | loss_dice=0.0858 | loss_iou=0.1568
# 93/100 * Epoch 93 (valid): dice=0.9094 | iou=0.8359 | loss=0.3820 | loss_bce=0.1591 | loss_dice=0.0906 | loss_iou=0.1641
# 94/100 * Epoch (train): 100% 41/41 [00:23<00:00,  1.73it/s, dice=0.943, iou=0.892, loss=0.246, loss_bce=0.100, loss_dice=0.057, loss_iou=0.108]
# 94/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.34it/s, dice=0.857, iou=0.749, loss=0.543, loss_bce=0.187, loss_dice=0.143, loss_iou=0.251]
# [2020-10-18 05:24:35,348]
# 94/100 * Epoch 94 (_base): lr=1.526e-08 | momentum=0.9000
# 94/100 * Epoch 94 (train): dice=0.9153 | iou=0.8453 | loss=0.3518 | loss_bce=0.1405 | loss_dice=0.0847 | loss_iou=0.1547
# 94/100 * Epoch 94 (valid): dice=0.9108 | iou=0.8384 | loss=0.3696 | loss_bce=0.1484 | loss_dice=0.0892 | loss_iou=0.1616
# 95/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.82it/s, dice=0.924, iou=0.858, loss=0.336, loss_bce=0.148, loss_dice=0.076, loss_iou=0.142]
# 95/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  3.90it/s, dice=0.856, iou=0.749, loss=0.538, loss_bce=0.179, loss_dice=0.144, loss_iou=0.251]
# [2020-10-18 05:25:00,671]
# 95/100 * Epoch 95 (_base): lr=1.526e-08 | momentum=0.9000
# 95/100 * Epoch 95 (train): dice=0.9172 | iou=0.8481 | loss=0.3517 | loss_bce=0.1461 | loss_dice=0.0828 | loss_iou=0.1519
# 95/100 * Epoch 95 (valid): dice=0.9116 | iou=0.8398 | loss=0.3565 | loss_bce=0.1348 | loss_dice=0.0884 | loss_iou=0.1602
# 96/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.88it/s, dice=0.907, iou=0.829, loss=0.447, loss_bce=0.229, loss_dice=0.093, loss_iou=0.171]
# 96/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.31it/s, dice=0.849, iou=0.737, loss=0.595, loss_bce=0.226, loss_dice=0.151, loss_iou=0.263]
# [2020-10-18 05:25:25,384]
# 96/100 * Epoch 96 (_base): lr=1.526e-08 | momentum=0.9000
# 96/100 * Epoch 96 (train): dice=0.9037 | iou=0.8272 | loss=0.4036 | loss_bce=0.1681 | loss_dice=0.0963 | loss_iou=0.1728
# 96/100 * Epoch 96 (valid): dice=0.9126 | iou=0.8416 | loss=0.3590 | loss_bce=0.1414 | loss_dice=0.0874 | loss_iou=0.1584
# 97/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.87it/s, dice=0.949, iou=0.903, loss=0.209, loss_bce=0.076, loss_dice=0.051, loss_iou=0.097]
# 97/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.43it/s, dice=0.855, iou=0.746, loss=0.539, loss_bce=0.175, loss_dice=0.145, loss_iou=0.254]
# [2020-10-18 05:25:49,851]
# 97/100 * Epoch 97 (_base): lr=1.526e-08 | momentum=0.9000
# 97/100 * Epoch 97 (train): dice=0.9094 | iou=0.8357 | loss=0.3819 | loss_bce=0.1587 | loss_dice=0.0906 | loss_iou=0.1643
# 97/100 * Epoch 97 (valid): dice=0.9090 | iou=0.8354 | loss=0.3642 | loss_bce=0.1358 | loss_dice=0.0910 | loss_iou=0.1646
# 98/100 * Epoch (train): 100% 41/41 [00:22<00:00,  1.80it/s, dice=0.937, iou=0.881, loss=0.283, loss_bce=0.125, loss_dice=0.063, loss_iou=0.119]
# 98/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.40it/s, dice=0.872, iou=0.773, loss=0.534, loss_bce=0.225, loss_dice=0.128, loss_iou=0.227]
# [2020-10-18 05:26:15,084]
# 98/100 * Epoch 98 (_base): lr=1.526e-08 | momentum=0.9000
# 98/100 * Epoch 98 (train): dice=0.9083 | iou=0.8343 | loss=0.3836 | loss_bce=0.1577 | loss_dice=0.0917 | loss_iou=0.1657
# 98/100 * Epoch 98 (valid): dice=0.9077 | iou=0.8329 | loss=0.3849 | loss_bce=0.1569 | loss_dice=0.0923 | loss_iou=0.1671
# 99/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.91it/s, dice=0.929, iou=0.867, loss=0.297, loss_bce=0.116, loss_dice=0.071, loss_iou=0.133]
# 99/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.34it/s, dice=0.853, iou=0.743, loss=0.555, loss_bce=0.188, loss_dice=0.147, loss_iou=0.257]
# [2020-10-18 05:26:39,040]
# 99/100 * Epoch 99 (_base): lr=1.526e-08 | momentum=0.9000
# 99/100 * Epoch 99 (train): dice=0.9112 | iou=0.8383 | loss=0.3702 | loss_bce=0.1497 | loss_dice=0.0888 | loss_iou=0.1617
# 99/100 * Epoch 99 (valid): dice=0.9127 | iou=0.8416 | loss=0.3546 | loss_bce=0.1362 | loss_dice=0.0873 | loss_iou=0.1584
# 100/100 * Epoch (train): 100% 41/41 [00:21<00:00,  1.92it/s, dice=0.899, iou=0.817, loss=0.389, loss_bce=0.131, loss_dice=0.101, loss_iou=0.183]
# 100/100 * Epoch (valid): 100% 10/10 [00:02<00:00,  4.40it/s, dice=0.833, iou=0.714, loss=0.710, loss_bce=0.321, loss_dice=0.167, loss_iou=0.286]
# [2020-10-18 05:27:02,910]
# 100/100 * Epoch 100 (_base): lr=1.526e-08 | momentum=0.9000
# 100/100 * Epoch 100 (train): dice=0.9063 | iou=0.8323 | loss=0.3887 | loss_bce=0.1592 | loss_dice=0.0937 | loss_iou=0.1677
# 100/100 * Epoch 100 (valid): dice=0.9031 | iou=0.8262 | loss=0.4089 | loss_bce=0.1727 | loss_dice=0.0969 | loss_iou=0.1738
# Top best models:
# logs/20201018-044538/checkpoints/train.59.pth	0.8438

# %% [markdown]
# ## Submission
#
# To generate submission, you'll have to write masks for images.
# Usually, in `Kaggle` segmentation competitions masks are encoded in the run length format.
# For more information, check `Evaluation` page in `Overview`.

# %%
def rle_encoding(x):
    """
    x: numpy array of shape (height, width), 1 - mask, 0 - background
    Returns run length as list
    """
    dots = np.where(x.T.flatten() == 1)[
        0
    ]  # .T sets Fortran order down-then-right
    run_lengths = []
    prev = -2
    for b in dots:
        if b > prev + 1:
            run_lengths.extend((b + 1, 0))
        run_lengths[-1] += 1
        prev = b
    return " ".join([str(i) for i in run_lengths])

# %% [markdown]
# This code below will generate a submission.
# It reads images from `test` folder and gathers prediction from the trained model.
# Check your submission before uploading it into `Kaggle`.

# %%
from PIL import Image
import pandas as pd

submission = {"ImageId": [], "EncodedPixels": []}
threshold = 0.5

test_transform = albu.Compose([
    albu.Resize(IMAGE_SIZE, IMAGE_SIZE),
    albu.Normalize(),
    ToTensor()
])


test_image_path = local_path / 'data3' / Path("test")
TEST_IMAGES = sorted(test_image_path.glob("*.png"))
test_dataset = SegmentationDataset(
    images=TEST_IMAGES,
    transforms=test_transform
)
test_loader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=num_workers,
)

for prediction in runner.predict_loader(loader=test_loader):
    submission["ImageId"].extend(s[:-4] for s in prediction["filename"])
    submission["EncodedPixels"].extend(
        rle_encoding(torch.sigmoid(mask.cpu()).numpy().squeeze(0) > threshold) for mask in prediction["mask"]
    )
