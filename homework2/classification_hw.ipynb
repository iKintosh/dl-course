# %% [markdown]
# # Classification task
#
# Hi! It's a classification task baseline notebook.
# It include a data reader, baseline model and submission generator.
#
# You should use GPU to train your model, so we recommend using [Kaggle Notebooks](https://www.kaggle.com/docs/notebooks).
# To get maximum score of the task, your model should have accuracy greater than `0.8`.
#
# You can use everything, that suits into the rules in `README.md`.

# %%
from pathlib import Path
from datetime import datetime
import numpy as np

import torch
import torch.nn as nn
from torch.utils import data

import catalyst
from catalyst import dl
from catalyst.utils import metrics, set_global_seed, get_available_gpus
from catalyst.utils import (
    create_dataset, create_dataframe, get_dataset_labeling, map_dataframe
)
from catalyst.utils import split_dataframe_train_test
from catalyst.data.cv.reader import ImageReader
from catalyst.dl import utils
from catalyst.data import ScalarReader, ReaderCompose
from catalyst.data import Augmentor
import albumentations as albu
from albumentations.pytorch import ToTensorV2 as ToTensor

from catalyst.dl import SupervisedRunner

import pandas as pd
from PIL import Image
from tqdm.notebook import tqdm

from GaborNet import GaborConv2d

# %%
set_global_seed(42)
get_available_gpus()
# Out:
# [0]

# %% [markdown]
# ## Dataset
#
# This code will help you to generate dataset. If your data have the following folder structure:
#
# ```
# dataset/
#     class_1/
#         *.ext
#         ...
#     class_2/
#         *.ext
#         ...
#     ...
#     class_N/
#         *.ext
#         ...
# ```
# First of all `create_dataset` function goes through a given directory and creates a dictionary `Dict[class_name, List[image]]`.
# Then `create_dataframe` function creates typical `pandas.DataFrame` for further analysis.
# After that, `prepare_dataset_labeling` creates a numerical label for each unique class name.
# Finally, to add a column with a numerical label value to the DataFrame, we can use `map_dataframe` function.
#
# Additionaly let's save the `class_names` for further usage.

# %%
path_to_dataset = str(Path.cwd().parent/"data2")

# %%
dataset = create_dataset(dirs=f"{path_to_dataset}/train/*", extension="*.jpg")
df = create_dataframe(dataset, columns=["class", "filepath"])

tag_to_label = get_dataset_labeling(df, "class")
class_names = [
    name for name, id_ in sorted(tag_to_label.items(), key=lambda x: x[1])
]

df_with_labels = map_dataframe(
    df, 
    tag_column="class", 
    class_column="label", 
    tag2class=tag_to_label, 
    verbose=False
)
df_with_labels.head()
# Out:
#       class                                           filepath  label
# 0  c1d6f6c4  /home/analekseev/PycharmProjects/dl-course/dat...      0
# 1  c1d6f6c4  /home/analekseev/PycharmProjects/dl-course/dat...      0
# 2  c1d6f6c4  /home/analekseev/PycharmProjects/dl-course/dat...      0
# 3  c1d6f6c4  /home/analekseev/PycharmProjects/dl-course/dat...      0
# 4  c1d6f6c4  /home/analekseev/PycharmProjects/dl-course/dat...      0

# %% [markdown]
# And you should split data in `train / valid / test` parts.
# There are only `train` and `valid` parts, so you must load test data as shows in a code cell.

# %%
train_data, valid_data = split_dataframe_train_test(
    df_with_labels, test_size=0.2, random_state=42
)
train_data, valid_data = (
    train_data.to_dict("records"),
    valid_data.to_dict("records"),
)

# %%
num_classes = len(tag_to_label)

open_fn = ReaderCompose(
    [
        ImageReader(
            input_key="filepath", output_key="features", rootpath="train"
        ),
        ScalarReader(
            input_key="label",
            output_key="targets",
            default_value=-1,
            dtype=np.int64,
        ),
        ScalarReader(
            input_key="label",
            output_key="targets_one_hot",
            default_value=-1,
            dtype=np.int64,
            one_hot_classes=num_classes,
        ),
    ]
)

# %% [markdown]
# ## Augmentation
#
# Use some augmentations to generate more images for training process.

# %%
IMAGE_SIZE = 224

train_transform = albu.Compose([
    albu.HorizontalFlip(p=0.25),
    albu.VerticalFlip(p=0.25),
    albu.RandomRotate90(p=0.25),
    albu.RandomBrightnessContrast(p=0.25),
    albu.LongestMaxSize(IMAGE_SIZE),
    albu.PadIfNeeded(IMAGE_SIZE, IMAGE_SIZE, border_mode=0),
    albu.RandomResizedCrop(IMAGE_SIZE, IMAGE_SIZE, p=0.5),
    albu.Normalize(),
    ToTensor()
])

valid_transform = albu.Compose([
    albu.LongestMaxSize(IMAGE_SIZE),
    albu.PadIfNeeded(IMAGE_SIZE, IMAGE_SIZE, border_mode=0),
    albu.RandomResizedCrop(IMAGE_SIZE, IMAGE_SIZE, p=0.25),
    albu.Normalize(),
    ToTensor()
])

# %%
train_data_transform = Augmentor(
    dict_key="features", augment_fn=lambda x: train_transform(image=x)["image"]
)

valid_data_transform = Augmentor(
    dict_key="features", augment_fn=lambda x: valid_transform(image=x)["image"]
)

# %% [markdown]
# Don't forget to create test loader.

# %%
batch_size = 128
num_workers = 4

train_loader = utils.get_loader(
    train_data,
    open_fn=open_fn,
    dict_transform=train_data_transform,
    batch_size=batch_size,
    num_workers=num_workers,
    shuffle=True,
    sampler=None,
    drop_last=True,
)

valid_loader = utils.get_loader(
    valid_data,
    open_fn=open_fn,
    dict_transform=valid_data_transform,
    batch_size=batch_size,
    num_workers=num_workers,
    shuffle=False, 
    sampler=None,
    drop_last=True,
)

loaders = {
    "train": train_loader,
    "valid": valid_loader
}

# %% [markdown]
# ## Model
#
# For the baseline, we will use a ResNet model, we already have examined in the seminar.
# Enhance the model, use any* instruments or module as you like.
#
# *(Don't forget about the rules!)

# %%
class ResNetBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride, p=0.1):
        super().__init__()

        self.input = nn.Sequential(
            nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size=3,
                stride=stride,
                padding=1,
            ),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(),
            nn.Conv2d(
                out_channels, out_channels, kernel_size=3, stride=1, padding=1
            ),
            nn.BatchNorm2d(out_channels),
        )
        self.res = nn.Conv2d(
            in_channels, out_channels, kernel_size=1, stride=stride
        )
        self.output = nn.Sequential(
            nn.BatchNorm2d(out_channels), 
            nn.LeakyReLU()
        )

    def forward(self, x):
        input_ = self.input(x)
        res = self.res(x)
        return self.output(res + input_)


class BaselineModel(nn.Module):
    def __init__(self, channels=3, in_features=64, num_classes=10, p=0.1):
        super().__init__()
        
        self.input = nn.Sequential(
            GaborConv2d(
                3, in_features, kernel_size=17, stride=2, padding=8,
            ),
            nn.BatchNorm2d(in_features),
            nn.LeakyReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )

        self.layer_0 = self._make_layer(in_features, 1)
        self.layer_1 = self._make_layer(in_features)
        in_features *= 2
        
        self.layer_2 = self._make_layer(in_features, 1)
        self.layer_3 = self._make_layer(in_features)
        in_features *= 2
        
        self.layer_4 = self._make_layer(in_features, 1)

        self.fc = nn.Sequential(
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Flatten(),
            nn.Linear(in_features, num_classes),
        )

    def _make_layer(self, in_features, multiplier=2, p=0.1):
        return nn.Sequential(
            ResNetBlock(in_features, in_features * multiplier, stride=2, p=p),
            ResNetBlock(
                in_features * multiplier,
                in_features * multiplier,
                stride=1,
                p=p,
            ),
        )

    def forward(self, x):
        x = self.input(x)
        x = self.layer_0(x)
        x = self.layer_1(x)
        x = self.layer_2(x)
        x = self.layer_3(x)
        x = self.layer_4(x)
        return self.fc(x)

# %% [markdown]
# from catalyst.dl import SupervisedRunner
#
# class ClassificationRunner(SupervisedRunner):
#     def predict_batch(self, batch):
#         prediction = {
#             "filepath": batch["filepath"],
#             "log_probs": self.model(batch[self.input_key].to(self.device))
#         }
#         return prediction

# %%
class ClassificationRunner(SupervisedRunner):
    def predict_batch(self, batch):
        prediction = {
            "filepath": batch["filepath"],
            "log_probs": self.model(batch[self.input_key].to(self.device))
        }
        return prediction

# %%
model = BaselineModel()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4)

runner = ClassificationRunner(input_key="features", input_target_key="targets")
runner.train(
    model=model,
    optimizer=optimizer,
    criterion=criterion,
    loaders=loaders,
    logdir=Path("logs") / datetime.now().strftime("%Y%m%d-%H%M%S"),
    num_epochs=100,
    verbose=True,
    load_best_on_end=True,
    callbacks={
        "optimizer": dl.OptimizerCallback(
            metric_key="loss", accumulation_steps=1, grad_clip_params=None,
        ),
        "criterion": dl.CriterionCallback(
            input_key="targets", output_key="logits", prefix="loss",
        ),
        "accuracy": dl.AccuracyCallback(num_classes=10),
    },
)
# Out:
# 1/100 * Epoch (train):   0% 0/56 [00:00<?, ?it/s]
# /home/analekseev/.cache/pypoetry/virtualenvs/dl-course-SIh-1RzJ-py3.8/lib/python3.8/site-packages/catalyst/callbacks/optimizer.py:140: UserWarning:
#
# This overload of add is deprecated:
# 	add(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
# 1/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.74it/s, accuracy01=0.359, accuracy03=0.664, accuracy05=0.820, loss=1.876]
# 1/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.82it/s, accuracy01=0.320, accuracy03=0.633, accuracy05=0.789, loss=1.953]
# [2020-10-17 17:37:55,659]
# 1/100 * Epoch 1 (_base): lr=0.0003 | momentum=0.9000
# 1/100 * Epoch 1 (train): accuracy01=0.2363 | accuracy03=0.5113 | accuracy05=0.7172 | loss=2.0883
# 1/100 * Epoch 1 (valid): accuracy01=0.2746 | accuracy03=0.6038 | accuracy05=0.7818 | loss=2.1236
# 2/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.72it/s, accuracy01=0.500, accuracy03=0.734, accuracy05=0.914, loss=1.586]
# 2/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.73it/s, accuracy01=0.414, accuracy03=0.719, accuracy05=0.875, loss=1.690]
# [2020-10-17 17:38:32,314]
# 2/100 * Epoch 2 (_base): lr=0.0003 | momentum=0.9000
# 2/100 * Epoch 2 (train): accuracy01=0.3892 | accuracy03=0.7181 | accuracy05=0.8641 | loss=1.7206
# 2/100 * Epoch 2 (valid): accuracy01=0.4174 | accuracy03=0.6858 | accuracy05=0.8203 | loss=1.8932
# 3/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.71it/s, accuracy01=0.461, accuracy03=0.781, accuracy05=0.914, loss=1.519]
# 3/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.67it/s, accuracy01=0.484, accuracy03=0.812, accuracy05=0.906, loss=1.436]
# [2020-10-17 17:39:09,620]
# 3/100 * Epoch 3 (_base): lr=0.0003 | momentum=0.9000
# 3/100 * Epoch 3 (train): accuracy01=0.4386 | accuracy03=0.7612 | accuracy05=0.8848 | loss=1.5979
# 3/100 * Epoch 3 (valid): accuracy01=0.4537 | accuracy03=0.7801 | accuracy05=0.8951 | loss=1.5864
# 4/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.69it/s, accuracy01=0.555, accuracy03=0.859, accuracy05=0.953, loss=1.291]
# 4/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.66it/s, accuracy01=0.414, accuracy03=0.672, accuracy05=0.844, loss=1.781]
# [2020-10-17 17:39:47,314]
# 4/100 * Epoch 4 (_base): lr=0.0003 | momentum=0.9000
# 4/100 * Epoch 4 (train): accuracy01=0.4865 | accuracy03=0.7946 | accuracy05=0.9089 | loss=1.4778
# 4/100 * Epoch 4 (valid): accuracy01=0.4364 | accuracy03=0.7243 | accuracy05=0.8806 | loss=1.7741
# 5/100 * Epoch (train): 100% 56/56 [00:34<00:00,  1.64it/s, accuracy01=0.625, accuracy03=0.859, accuracy05=0.953, loss=1.174]
# 5/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.61it/s, accuracy01=0.492, accuracy03=0.766, accuracy05=0.906, loss=1.519]
# [2020-10-17 17:40:25,882]
# 5/100 * Epoch 5 (_base): lr=0.0003 | momentum=0.9000
# 5/100 * Epoch 5 (train): accuracy01=0.5110 | accuracy03=0.8009 | accuracy05=0.9071 | loss=1.4266
# 5/100 * Epoch 5 (valid): accuracy01=0.5156 | accuracy03=0.7941 | accuracy05=0.9068 | loss=1.4804
# 6/100 * Epoch (train): 100% 56/56 [00:35<00:00,  1.58it/s, accuracy01=0.508, accuracy03=0.836, accuracy05=0.898, loss=1.436]
# 6/100 * Epoch (valid): 100% 14/14 [00:05<00:00,  2.73it/s, accuracy01=0.461, accuracy03=0.750, accuracy05=0.859, loss=1.693]
# [2020-10-17 17:41:07,174]
# 6/100 * Epoch 6 (_base): lr=0.0003 | momentum=0.9000
# 6/100 * Epoch 6 (train): accuracy01=0.5487 | accuracy03=0.8244 | accuracy05=0.9240 | loss=1.3414
# 6/100 * Epoch 6 (valid): accuracy01=0.4581 | accuracy03=0.7327 | accuracy05=0.8677 | loss=1.7390
# 7/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.68it/s, accuracy01=0.555, accuracy03=0.828, accuracy05=0.922, loss=1.319]
# 7/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.57it/s, accuracy01=0.648, accuracy03=0.883, accuracy05=0.914, loss=1.142]
# [2020-10-17 17:41:44,840]
# 7/100 * Epoch 7 (_base): lr=0.0003 | momentum=0.9000
# 7/100 * Epoch 7 (train): accuracy01=0.5749 | accuracy03=0.8411 | accuracy05=0.9282 | loss=1.2833
# 7/100 * Epoch 7 (valid): accuracy01=0.5720 | accuracy03=0.8477 | accuracy05=0.9275 | loss=1.3383
# 8/100 * Epoch (train): 100% 56/56 [00:34<00:00,  1.63it/s, accuracy01=0.633, accuracy03=0.859, accuracy05=0.930, loss=1.152]
# 8/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.57it/s, accuracy01=0.633, accuracy03=0.883, accuracy05=0.922, loss=1.156]
# [2020-10-17 17:42:23,782]
# 8/100 * Epoch 8 (_base): lr=0.0003 | momentum=0.9000
# 8/100 * Epoch 8 (train): accuracy01=0.6011 | accuracy03=0.8460 | accuracy05=0.9329 | loss=1.2208
# 8/100 * Epoch 8 (valid): accuracy01=0.5938 | accuracy03=0.8426 | accuracy05=0.9247 | loss=1.2500
# 9/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.65it/s, accuracy01=0.625, accuracy03=0.859, accuracy05=0.930, loss=1.072]
# 9/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.61it/s, accuracy01=0.562, accuracy03=0.836, accuracy05=0.930, loss=1.209]
# [2020-10-17 17:43:02,249]
# 9/100 * Epoch 9 (_base): lr=0.0003 | momentum=0.9000
# 9/100 * Epoch 9 (train): accuracy01=0.6053 | accuracy03=0.8556 | accuracy05=0.9361 | loss=1.1916
# 9/100 * Epoch 9 (valid): accuracy01=0.5848 | accuracy03=0.8488 | accuracy05=0.9291 | loss=1.2389
# 10/100 * Epoch (train): 100% 56/56 [00:35<00:00,  1.58it/s, accuracy01=0.641, accuracy03=0.883, accuracy05=0.953, loss=1.042]
# 10/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.61it/s, accuracy01=0.523, accuracy03=0.836, accuracy05=0.922, loss=1.656]
# [2020-10-17 17:43:42,372]
# 10/100 * Epoch 10 (_base): lr=0.0003 | momentum=0.9000
# 10/100 * Epoch 10 (train): accuracy01=0.6278 | accuracy03=0.8650 | accuracy05=0.9404 | loss=1.1319
# 10/100 * Epoch 10 (valid): accuracy01=0.5017 | accuracy03=0.7857 | accuracy05=0.8990 | loss=1.7616
# 11/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.66it/s, accuracy01=0.703, accuracy03=0.883, accuracy05=0.969, loss=0.982]
# 11/100 * Epoch (valid): 100% 14/14 [00:04<00:00,  3.49it/s, accuracy01=0.562, accuracy03=0.867, accuracy05=0.953, loss=1.114]
# [2020-10-17 17:44:20,561]
# 11/100 * Epoch 11 (_base): lr=0.0003 | momentum=0.9000
# 11/100 * Epoch 11 (train): accuracy01=0.6451 | accuracy03=0.8703 | accuracy05=0.9425 | loss=1.0959
# 11/100 * Epoch 11 (valid): accuracy01=0.5698 | accuracy03=0.8175 | accuracy05=0.9208 | loss=1.3566
# 12/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.66it/s, accuracy01=0.641, accuracy03=0.906, accuracy05=0.953, loss=1.032]
# 12/100 * Epoch (valid): 100% 14/14 [00:04<00:00,  3.47it/s, accuracy01=0.414, accuracy03=0.703, accuracy05=0.852, loss=2.147]
# [2020-10-17 17:44:58,811]
# 12/100 * Epoch 12 (_base): lr=0.0003 | momentum=0.9000
# 12/100 * Epoch 12 (train): accuracy01=0.6593 | accuracy03=0.8781 | accuracy05=0.9481 | loss=1.0467
# 12/100 * Epoch 12 (valid): accuracy01=0.4336 | accuracy03=0.7098 | accuracy05=0.8432 | loss=2.0355
# 13/100 * Epoch (train): 100% 56/56 [00:34<00:00,  1.61it/s, accuracy01=0.719, accuracy03=0.922, accuracy05=1.000, loss=0.857]
# 13/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.59it/s, accuracy01=0.609, accuracy03=0.859, accuracy05=0.922, loss=1.183]
# [2020-10-17 17:45:38,243]
# 13/100 * Epoch 13 (_base): lr=0.0003 | momentum=0.9000
# 13/100 * Epoch 13 (train): accuracy01=0.6625 | accuracy03=0.8799 | accuracy05=0.9502 | loss=1.0258
# 13/100 * Epoch 13 (valid): accuracy01=0.5993 | accuracy03=0.8443 | accuracy05=0.9308 | loss=1.2289
# 14/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.67it/s, accuracy01=0.695, accuracy03=0.867, accuracy05=0.961, loss=1.031]
# 14/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.54it/s, accuracy01=0.766, accuracy03=0.914, accuracy05=0.945, loss=0.792]
# [2020-10-17 17:46:16,445]
# 14/100 * Epoch 14 (_base): lr=0.0003 | momentum=0.9000
# 14/100 * Epoch 14 (train): accuracy01=0.6801 | accuracy03=0.8867 | accuracy05=0.9534 | loss=0.9951
# 14/100 * Epoch 14 (valid): accuracy01=0.7098 | accuracy03=0.8917 | accuracy05=0.9531 | loss=0.9246
# 15/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.67it/s, accuracy01=0.680, accuracy03=0.906, accuracy05=0.953, loss=0.974]
# 15/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.55it/s, accuracy01=0.664, accuracy03=0.844, accuracy05=0.938, loss=1.066]
# [2020-10-17 17:46:54,716]
# 15/100 * Epoch 15 (_base): lr=0.0003 | momentum=0.9000
# 15/100 * Epoch 15 (train): accuracy01=0.6851 | accuracy03=0.8949 | accuracy05=0.9531 | loss=0.9651
# 15/100 * Epoch 15 (valid): accuracy01=0.6484 | accuracy03=0.8504 | accuracy05=0.9247 | loss=1.1102
# 16/100 * Epoch (train): 100% 56/56 [00:35<00:00,  1.57it/s, accuracy01=0.680, accuracy03=0.914, accuracy05=0.992, loss=0.887]
# 16/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.58it/s, accuracy01=0.664, accuracy03=0.906, accuracy05=0.961, loss=0.994]
# [2020-10-17 17:47:34,839]
# 16/100 * Epoch 16 (_base): lr=0.0003 | momentum=0.9000
# 16/100 * Epoch 16 (train): accuracy01=0.6837 | accuracy03=0.8929 | accuracy05=0.9542 | loss=0.9590
# 16/100 * Epoch 16 (valid): accuracy01=0.6590 | accuracy03=0.8845 | accuracy05=0.9559 | loss=1.0236
# 17/100 * Epoch (train): 100% 56/56 [00:34<00:00,  1.62it/s, accuracy01=0.656, accuracy03=0.883, accuracy05=0.969, loss=1.114]
# 17/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.61it/s, accuracy01=0.641, accuracy03=0.859, accuracy05=0.938, loss=1.072]
# [2020-10-17 17:48:13,669]
# 17/100 * Epoch 17 (_base): lr=0.0003 | momentum=0.9000
# 17/100 * Epoch 17 (train): accuracy01=0.7069 | accuracy03=0.9030 | accuracy05=0.9584 | loss=0.9094
# 17/100 * Epoch 17 (valid): accuracy01=0.6440 | accuracy03=0.8689 | accuracy05=0.9492 | loss=1.1087
# 18/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.69it/s, accuracy01=0.695, accuracy03=0.898, accuracy05=0.961, loss=0.865]
# 18/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.64it/s, accuracy01=0.734, accuracy03=0.891, accuracy05=0.945, loss=0.975]
# [2020-10-17 17:48:51,162]
# 18/100 * Epoch 18 (_base): lr=0.0003 | momentum=0.9000
# 18/100 * Epoch 18 (train): accuracy01=0.6999 | accuracy03=0.9065 | accuracy05=0.9618 | loss=0.9113
# 18/100 * Epoch 18 (valid): accuracy01=0.6959 | accuracy03=0.8979 | accuracy05=0.9537 | loss=0.9529
# 19/100 * Epoch (train): 100% 56/56 [00:34<00:00,  1.61it/s, accuracy01=0.758, accuracy03=0.875, accuracy05=0.930, loss=0.875]
# 19/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.64it/s, accuracy01=0.609, accuracy03=0.875, accuracy05=0.969, loss=1.183]
# [2020-10-17 17:49:30,231]
# 19/100 * Epoch 19 (_base): lr=0.0003 | momentum=0.9000
# 19/100 * Epoch 19 (train): accuracy01=0.7161 | accuracy03=0.9103 | accuracy05=0.9629 | loss=0.8705
# 19/100 * Epoch 19 (valid): accuracy01=0.6150 | accuracy03=0.8365 | accuracy05=0.9219 | loss=1.2573
# 20/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.70it/s, accuracy01=0.711, accuracy03=0.891, accuracy05=0.961, loss=0.930]
# 20/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.64it/s, accuracy01=0.766, accuracy03=0.867, accuracy05=0.938, loss=0.886]
# [2020-10-17 17:50:07,932]
# 20/100 * Epoch 20 (_base): lr=0.0003 | momentum=0.9000
# 20/100 * Epoch 20 (train): accuracy01=0.7160 | accuracy03=0.9039 | accuracy05=0.9621 | loss=0.8792
# 20/100 * Epoch 20 (valid): accuracy01=0.6819 | accuracy03=0.8912 | accuracy05=0.9520 | loss=0.9627
# 21/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.68it/s, accuracy01=0.648, accuracy03=0.883, accuracy05=0.930, loss=0.947]
# 21/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.76it/s, accuracy01=0.461, accuracy03=0.711, accuracy05=0.812, loss=2.162]
# [2020-10-17 17:50:45,461]
# 21/100 * Epoch 21 (_base): lr=0.0003 | momentum=0.9000
# 21/100 * Epoch 21 (train): accuracy01=0.7280 | accuracy03=0.9113 | accuracy05=0.9619 | loss=0.8432
# 21/100 * Epoch 21 (valid): accuracy01=0.4196 | accuracy03=0.7003 | accuracy05=0.8186 | loss=2.2444
# 22/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.69it/s, accuracy01=0.719, accuracy03=0.930, accuracy05=0.977, loss=0.765]
# 22/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.76it/s, accuracy01=0.695, accuracy03=0.891, accuracy05=0.945, loss=0.930]
# [2020-10-17 17:51:22,786]
# 22/100 * Epoch 22 (_base): lr=0.0003 | momentum=0.9000
# 22/100 * Epoch 22 (train): accuracy01=0.7288 | accuracy03=0.9141 | accuracy05=0.9614 | loss=0.8366
# 22/100 * Epoch 22 (valid): accuracy01=0.7070 | accuracy03=0.8912 | accuracy05=0.9570 | loss=0.8960
# 23/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.69it/s, accuracy01=0.734, accuracy03=0.961, accuracy05=0.984, loss=0.752]
# 23/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.71it/s, accuracy01=0.719, accuracy03=0.930, accuracy05=0.953, loss=0.749]
# [2020-10-17 17:52:00,487]
# 23/100 * Epoch 23 (_base): lr=0.0003 | momentum=0.9000
# 23/100 * Epoch 23 (train): accuracy01=0.7383 | accuracy03=0.9134 | accuracy05=0.9660 | loss=0.8092
# 23/100 * Epoch 23 (valid): accuracy01=0.7517 | accuracy03=0.9135 | accuracy05=0.9637 | loss=0.7656
# 24/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.68it/s, accuracy01=0.727, accuracy03=0.922, accuracy05=0.969, loss=0.874]
# 24/100 * Epoch (valid): 100% 14/14 [00:05<00:00,  2.69it/s, accuracy01=0.766, accuracy03=0.875, accuracy05=0.922, loss=0.817]
# [2020-10-17 17:52:39,922]
# 24/100 * Epoch 24 (_base): lr=0.0003 | momentum=0.9000
# 24/100 * Epoch 24 (train): accuracy01=0.7482 | accuracy03=0.9234 | accuracy05=0.9683 | loss=0.7877
# 24/100 * Epoch 24 (valid): accuracy01=0.7193 | accuracy03=0.9001 | accuracy05=0.9632 | loss=0.8511
# 25/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.68it/s, accuracy01=0.727, accuracy03=0.938, accuracy05=0.977, loss=0.819]
# 25/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.62it/s, accuracy01=0.656, accuracy03=0.852, accuracy05=0.945, loss=1.123]
# [2020-10-17 17:53:17,477]
# 25/100 * Epoch 25 (_base): lr=0.0003 | momentum=0.9000
# 25/100 * Epoch 25 (train): accuracy01=0.7480 | accuracy03=0.9148 | accuracy05=0.9672 | loss=0.7868
# 25/100 * Epoch 25 (valid): accuracy01=0.6429 | accuracy03=0.8672 | accuracy05=0.9515 | loss=1.1544
# 26/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.66it/s, accuracy01=0.766, accuracy03=0.898, accuracy05=0.961, loss=0.862]
# 26/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.73it/s, accuracy01=0.680, accuracy03=0.883, accuracy05=0.961, loss=1.117]
# [2020-10-17 17:53:55,409]
# 26/100 * Epoch 26 (_base): lr=0.0003 | momentum=0.9000
# 26/100 * Epoch 26 (train): accuracy01=0.7493 | accuracy03=0.9237 | accuracy05=0.9694 | loss=0.7726
# 26/100 * Epoch 26 (valid): accuracy01=0.6613 | accuracy03=0.8789 | accuracy05=0.9531 | loss=1.0712
# 27/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.68it/s, accuracy01=0.695, accuracy03=0.883, accuracy05=0.953, loss=0.890]
# 27/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.61it/s, accuracy01=0.609, accuracy03=0.875, accuracy05=0.930, loss=1.486]
# [2020-10-17 17:54:33,177]
# 27/100 * Epoch 27 (_base): lr=0.0003 | momentum=0.9000
# 27/100 * Epoch 27 (train): accuracy01=0.7602 | accuracy03=0.9198 | accuracy05=0.9679 | loss=0.7547
# 27/100 * Epoch 27 (valid): accuracy01=0.5815 | accuracy03=0.8583 | accuracy05=0.9347 | loss=1.5730
# 28/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.69it/s, accuracy01=0.797, accuracy03=0.922, accuracy05=0.969, loss=0.648]
# 28/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.73it/s, accuracy01=0.742, accuracy03=0.930, accuracy05=0.977, loss=0.872]
# [2020-10-17 17:55:10,710]
# 28/100 * Epoch 28 (_base): lr=0.0003 | momentum=0.9000
# 28/100 * Epoch 28 (train): accuracy01=0.7588 | accuracy03=0.9217 | accuracy05=0.9701 | loss=0.7395
# 28/100 * Epoch 28 (valid): accuracy01=0.7031 | accuracy03=0.8996 | accuracy05=0.9570 | loss=0.9490
# 29/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.69it/s, accuracy01=0.695, accuracy03=0.906, accuracy05=0.953, loss=0.950]
# 29/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.68it/s, accuracy01=0.797, accuracy03=0.938, accuracy05=0.977, loss=0.598]
# [2020-10-17 17:55:48,082]
# 29/100 * Epoch 29 (_base): lr=0.0003 | momentum=0.9000
# 29/100 * Epoch 29 (train): accuracy01=0.7683 | accuracy03=0.9333 | accuracy05=0.9742 | loss=0.7137
# 29/100 * Epoch 29 (valid): accuracy01=0.7684 | accuracy03=0.9241 | accuracy05=0.9660 | loss=0.7278
# 30/100 * Epoch (train): 100% 56/56 [00:34<00:00,  1.64it/s, accuracy01=0.727, accuracy03=0.883, accuracy05=0.945, loss=0.844]
# 30/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.71it/s, accuracy01=0.742, accuracy03=0.938, accuracy05=0.961, loss=0.848]
# [2020-10-17 17:56:26,630]
# 30/100 * Epoch 30 (_base): lr=0.0003 | momentum=0.9000
# 30/100 * Epoch 30 (train): accuracy01=0.7679 | accuracy03=0.9325 | accuracy05=0.9732 | loss=0.7131
# 30/100 * Epoch 30 (valid): accuracy01=0.7054 | accuracy03=0.9096 | accuracy05=0.9621 | loss=0.9316
# 31/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.70it/s, accuracy01=0.781, accuracy03=0.930, accuracy05=0.961, loss=0.711]
# 31/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.72it/s, accuracy01=0.750, accuracy03=0.922, accuracy05=0.953, loss=0.838]
# [2020-10-17 17:57:04,364]
# 31/100 * Epoch 31 (_base): lr=0.0003 | momentum=0.9000
# 31/100 * Epoch 31 (train): accuracy01=0.7662 | accuracy03=0.9325 | accuracy05=0.9717 | loss=0.7114
# 31/100 * Epoch 31 (valid): accuracy01=0.7321 | accuracy03=0.9074 | accuracy05=0.9587 | loss=0.8619
# 32/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.69it/s, accuracy01=0.789, accuracy03=0.945, accuracy05=0.977, loss=0.693]
# 32/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.69it/s, accuracy01=0.750, accuracy03=0.938, accuracy05=0.969, loss=0.699]
# [2020-10-17 17:57:41,681]
# 32/100 * Epoch 32 (_base): lr=0.0003 | momentum=0.9000
# 32/100 * Epoch 32 (train): accuracy01=0.7807 | accuracy03=0.9340 | accuracy05=0.9704 | loss=0.6763
# 32/100 * Epoch 32 (valid): accuracy01=0.7561 | accuracy03=0.9180 | accuracy05=0.9710 | loss=0.7565
# 33/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.66it/s, accuracy01=0.727, accuracy03=0.906, accuracy05=0.953, loss=0.834]
# 33/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.72it/s, accuracy01=0.773, accuracy03=0.914, accuracy05=0.969, loss=0.769]
# [2020-10-17 17:58:19,684]
# 33/100 * Epoch 33 (_base): lr=0.0003 | momentum=0.9000
# 33/100 * Epoch 33 (train): accuracy01=0.7852 | accuracy03=0.9365 | accuracy05=0.9729 | loss=0.6647
# 33/100 * Epoch 33 (valid): accuracy01=0.7467 | accuracy03=0.9141 | accuracy05=0.9665 | loss=0.7871
# 34/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.69it/s, accuracy01=0.836, accuracy03=0.961, accuracy05=1.000, loss=0.582]
# 34/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.63it/s, accuracy01=0.828, accuracy03=0.953, accuracy05=0.977, loss=0.603]
# [2020-10-17 17:58:57,160]
# 34/100 * Epoch 34 (_base): lr=0.0003 | momentum=0.9000
# 34/100 * Epoch 34 (train): accuracy01=0.7831 | accuracy03=0.9388 | accuracy05=0.9781 | loss=0.6618
# 34/100 * Epoch 34 (valid): accuracy01=0.7913 | accuracy03=0.9308 | accuracy05=0.9715 | loss=0.6846
# 35/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.70it/s, accuracy01=0.781, accuracy03=0.930, accuracy05=0.969, loss=0.730]
# 35/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.73it/s, accuracy01=0.758, accuracy03=0.906, accuracy05=0.953, loss=0.819]
# [2020-10-17 17:59:34,956]
# 35/100 * Epoch 35 (_base): lr=0.0003 | momentum=0.9000
# 35/100 * Epoch 35 (train): accuracy01=0.7860 | accuracy03=0.9402 | accuracy05=0.9768 | loss=0.6564
# 35/100 * Epoch 35 (valid): accuracy01=0.7606 | accuracy03=0.9314 | accuracy05=0.9715 | loss=0.7302
# 36/100 * Epoch (train): 100% 56/56 [00:34<00:00,  1.64it/s, accuracy01=0.781, accuracy03=0.922, accuracy05=0.977, loss=0.616]
# 36/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.81it/s, accuracy01=0.789, accuracy03=0.930, accuracy05=0.961, loss=0.659]
# [2020-10-17 18:00:13,277]
# 36/100 * Epoch 36 (_base): lr=0.0003 | momentum=0.9000
# 36/100 * Epoch 36 (train): accuracy01=0.7970 | accuracy03=0.9399 | accuracy05=0.9756 | loss=0.6356
# 36/100 * Epoch 36 (valid): accuracy01=0.7690 | accuracy03=0.9258 | accuracy05=0.9704 | loss=0.7307
# 37/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.66it/s, accuracy01=0.820, accuracy03=0.961, accuracy05=0.992, loss=0.580]
# 37/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.78it/s, accuracy01=0.664, accuracy03=0.914, accuracy05=0.984, loss=1.081]
# [2020-10-17 18:00:51,094]
# 37/100 * Epoch 37 (_base): lr=0.0003 | momentum=0.9000
# 37/100 * Epoch 37 (train): accuracy01=0.7902 | accuracy03=0.9399 | accuracy05=0.9766 | loss=0.6466
# 37/100 * Epoch 37 (valid): accuracy01=0.6646 | accuracy03=0.8862 | accuracy05=0.9498 | loss=1.0950
# 38/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.758, accuracy03=0.914, accuracy05=0.961, loss=0.782]
# 38/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.72it/s, accuracy01=0.805, accuracy03=0.922, accuracy05=0.969, loss=0.644]
# [2020-10-17 18:01:28,276]
# 38/100 * Epoch 38 (_base): lr=0.0003 | momentum=0.9000
# 38/100 * Epoch 38 (train): accuracy01=0.7984 | accuracy03=0.9418 | accuracy05=0.9784 | loss=0.6212
# 38/100 * Epoch 38 (valid): accuracy01=0.7628 | accuracy03=0.9235 | accuracy05=0.9704 | loss=0.7201
# 39/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.766, accuracy03=0.945, accuracy05=0.992, loss=0.730]
# 39/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.70it/s, accuracy01=0.844, accuracy03=0.914, accuracy05=0.969, loss=0.574]
# [2020-10-17 18:02:05,464]
# 39/100 * Epoch 39 (_base): lr=0.0003 | momentum=0.9000
# 39/100 * Epoch 39 (train): accuracy01=0.7995 | accuracy03=0.9400 | accuracy05=0.9789 | loss=0.6241
# 39/100 * Epoch 39 (valid): accuracy01=0.7824 | accuracy03=0.9241 | accuracy05=0.9721 | loss=0.6821
# 40/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.820, accuracy03=0.930, accuracy05=0.969, loss=0.673]
# 40/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.70it/s, accuracy01=0.758, accuracy03=0.930, accuracy05=0.961, loss=0.807]
# [2020-10-17 18:02:43,211]
# 40/100 * Epoch 40 (_base): lr=0.0003 | momentum=0.9000
# 40/100 * Epoch 40 (train): accuracy01=0.8076 | accuracy03=0.9443 | accuracy05=0.9805 | loss=0.6037
# 40/100 * Epoch 40 (valid): accuracy01=0.7400 | accuracy03=0.9090 | accuracy05=0.9637 | loss=0.8609
# 41/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.820, accuracy03=0.953, accuracy05=0.969, loss=0.496]
# 41/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.73it/s, accuracy01=0.680, accuracy03=0.906, accuracy05=0.961, loss=0.949]
# [2020-10-17 18:03:20,757]
# 41/100 * Epoch 41 (_base): lr=0.0003 | momentum=0.9000
# 41/100 * Epoch 41 (train): accuracy01=0.8136 | accuracy03=0.9470 | accuracy05=0.9802 | loss=0.5792
# 41/100 * Epoch 41 (valid): accuracy01=0.7249 | accuracy03=0.9157 | accuracy05=0.9615 | loss=0.9023
# 42/100 * Epoch (train): 100% 56/56 [00:34<00:00,  1.63it/s, accuracy01=0.859, accuracy03=0.961, accuracy05=0.984, loss=0.469]
# 42/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.72it/s, accuracy01=0.703, accuracy03=0.938, accuracy05=0.961, loss=0.913]
# [2020-10-17 18:03:59,227]
# 42/100 * Epoch 42 (_base): lr=0.0003 | momentum=0.9000
# 42/100 * Epoch 42 (train): accuracy01=0.8068 | accuracy03=0.9455 | accuracy05=0.9807 | loss=0.6061
# 42/100 * Epoch 42 (valid): accuracy01=0.7561 | accuracy03=0.9353 | accuracy05=0.9749 | loss=0.7810
# 43/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.70it/s, accuracy01=0.828, accuracy03=0.953, accuracy05=0.977, loss=0.575]
# 43/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.75it/s, accuracy01=0.812, accuracy03=0.938, accuracy05=0.977, loss=0.681]
# [2020-10-17 18:04:36,427]
# 43/100 * Epoch 43 (_base): lr=0.0003 | momentum=0.9000
# 43/100 * Epoch 43 (train): accuracy01=0.8098 | accuracy03=0.9480 | accuracy05=0.9810 | loss=0.5785
# 43/100 * Epoch 43 (valid): accuracy01=0.7634 | accuracy03=0.9275 | accuracy05=0.9699 | loss=0.7517
# 44/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.69it/s, accuracy01=0.797, accuracy03=0.930, accuracy05=0.977, loss=0.644]
# 44/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.71it/s, accuracy01=0.750, accuracy03=0.914, accuracy05=0.969, loss=0.676]
# [2020-10-17 18:05:13,754]
# 44/100 * Epoch 44 (_base): lr=0.0003 | momentum=0.9000
# 44/100 * Epoch 44 (train): accuracy01=0.8092 | accuracy03=0.9492 | accuracy05=0.9812 | loss=0.5823
# 44/100 * Epoch 44 (valid): accuracy01=0.7723 | accuracy03=0.9169 | accuracy05=0.9654 | loss=0.7514
# 45/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.69it/s, accuracy01=0.828, accuracy03=0.961, accuracy05=0.992, loss=0.516]
# 45/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.68it/s, accuracy01=0.734, accuracy03=0.914, accuracy05=0.969, loss=0.869]
# [2020-10-17 18:05:51,055]
# 45/100 * Epoch 45 (_base): lr=0.0003 | momentum=0.9000
# 45/100 * Epoch 45 (train): accuracy01=0.8214 | accuracy03=0.9488 | accuracy05=0.9803 | loss=0.5589
# 45/100 * Epoch 45 (valid): accuracy01=0.7567 | accuracy03=0.9241 | accuracy05=0.9743 | loss=0.8027
# 46/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.69it/s, accuracy01=0.820, accuracy03=0.914, accuracy05=0.961, loss=0.652]
# 46/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.78it/s, accuracy01=0.773, accuracy03=0.930, accuracy05=0.961, loss=0.721]
# [2020-10-17 18:06:28,266]
# 46/100 * Epoch 46 (_base): lr=0.0003 | momentum=0.9000
# 46/100 * Epoch 46 (train): accuracy01=0.8129 | accuracy03=0.9480 | accuracy05=0.9807 | loss=0.5760
# 46/100 * Epoch 46 (valid): accuracy01=0.7734 | accuracy03=0.9263 | accuracy05=0.9688 | loss=0.7685
# 47/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.773, accuracy03=0.922, accuracy05=0.969, loss=0.675]
# 47/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.72it/s, accuracy01=0.781, accuracy03=0.914, accuracy05=0.984, loss=0.717]
# [2020-10-17 18:07:06,573]
# 47/100 * Epoch 47 (_base): lr=0.0003 | momentum=0.9000
# 47/100 * Epoch 47 (train): accuracy01=0.8242 | accuracy03=0.9544 | accuracy05=0.9820 | loss=0.5461
# 47/100 * Epoch 47 (valid): accuracy01=0.7511 | accuracy03=0.9135 | accuracy05=0.9654 | loss=0.8021
# 48/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.898, accuracy03=0.969, accuracy05=0.992, loss=0.415]
# 48/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.68it/s, accuracy01=0.703, accuracy03=0.914, accuracy05=0.961, loss=0.929]
# [2020-10-17 18:07:43,687]
# 48/100 * Epoch 48 (_base): lr=0.0003 | momentum=0.9000
# 48/100 * Epoch 48 (train): accuracy01=0.8258 | accuracy03=0.9516 | accuracy05=0.9806 | loss=0.5395
# 48/100 * Epoch 48 (valid): accuracy01=0.6970 | accuracy03=0.8923 | accuracy05=0.9520 | loss=1.0760
# 49/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.70it/s, accuracy01=0.805, accuracy03=0.977, accuracy05=0.992, loss=0.518]
# 49/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.75it/s, accuracy01=0.766, accuracy03=0.945, accuracy05=0.969, loss=0.733]
# [2020-10-17 18:08:20,864]
# 49/100 * Epoch 49 (_base): lr=0.0003 | momentum=0.9000
# 49/100 * Epoch 49 (train): accuracy01=0.8199 | accuracy03=0.9530 | accuracy05=0.9816 | loss=0.5471
# 49/100 * Epoch 49 (valid): accuracy01=0.7757 | accuracy03=0.9420 | accuracy05=0.9738 | loss=0.6901
# 50/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.70it/s, accuracy01=0.852, accuracy03=0.969, accuracy05=0.992, loss=0.476]
# 50/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.68it/s, accuracy01=0.797, accuracy03=0.961, accuracy05=1.000, loss=0.605]
# [2020-10-17 18:08:58,112]
# 50/100 * Epoch 50 (_base): lr=0.0003 | momentum=0.9000
# 50/100 * Epoch 50 (train): accuracy01=0.8245 | accuracy03=0.9528 | accuracy05=0.9816 | loss=0.5438
# 50/100 * Epoch 50 (valid): accuracy01=0.8019 | accuracy03=0.9353 | accuracy05=0.9721 | loss=0.6640
# 51/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.69it/s, accuracy01=0.852, accuracy03=0.977, accuracy05=1.000, loss=0.464]
# 51/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.75it/s, accuracy01=0.836, accuracy03=0.945, accuracy05=0.977, loss=0.551]
# [2020-10-17 18:09:35,584]
# 51/100 * Epoch 51 (_base): lr=0.0003 | momentum=0.9000
# 51/100 * Epoch 51 (train): accuracy01=0.8288 | accuracy03=0.9563 | accuracy05=0.9833 | loss=0.5274
# 51/100 * Epoch 51 (valid): accuracy01=0.7762 | accuracy03=0.9263 | accuracy05=0.9715 | loss=0.7281
# 52/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.867, accuracy03=0.961, accuracy05=0.977, loss=0.493]
# 52/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.72it/s, accuracy01=0.836, accuracy03=0.969, accuracy05=0.984, loss=0.617]
# [2020-10-17 18:10:12,792]
# 52/100 * Epoch 52 (_base): lr=0.0003 | momentum=0.9000
# 52/100 * Epoch 52 (train): accuracy01=0.8351 | accuracy03=0.9552 | accuracy05=0.9821 | loss=0.5045
# 52/100 * Epoch 52 (valid): accuracy01=0.8002 | accuracy03=0.9302 | accuracy05=0.9693 | loss=0.6491
# 53/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.820, accuracy03=0.930, accuracy05=0.953, loss=0.554]
# 53/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.73it/s, accuracy01=0.664, accuracy03=0.914, accuracy05=0.977, loss=1.002]
# [2020-10-17 18:10:50,213]
# 53/100 * Epoch 53 (_base): lr=0.0003 | momentum=0.9000
# 53/100 * Epoch 53 (train): accuracy01=0.8267 | accuracy03=0.9523 | accuracy05=0.9816 | loss=0.5275
# 53/100 * Epoch 53 (valid): accuracy01=0.7254 | accuracy03=0.9118 | accuracy05=0.9587 | loss=0.9409
# 54/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.812, accuracy03=0.945, accuracy05=0.969, loss=0.520]
# 54/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.76it/s, accuracy01=0.867, accuracy03=0.953, accuracy05=0.977, loss=0.526]
# [2020-10-17 18:11:27,304]
# 54/100 * Epoch 54 (_base): lr=0.0003 | momentum=0.9000
# 54/100 * Epoch 54 (train): accuracy01=0.8327 | accuracy03=0.9545 | accuracy05=0.9828 | loss=0.5204
# 54/100 * Epoch 54 (valid): accuracy01=0.8080 | accuracy03=0.9487 | accuracy05=0.9794 | loss=0.6311
# 55/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.812, accuracy03=0.953, accuracy05=0.977, loss=0.577]
# 55/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.75it/s, accuracy01=0.727, accuracy03=0.930, accuracy05=0.961, loss=0.820]
# [2020-10-17 18:12:04,711]
# 55/100 * Epoch 55 (_base): lr=0.0003 | momentum=0.9000
# 55/100 * Epoch 55 (train): accuracy01=0.8414 | accuracy03=0.9574 | accuracy05=0.9854 | loss=0.4902
# 55/100 * Epoch 55 (valid): accuracy01=0.7165 | accuracy03=0.8934 | accuracy05=0.9632 | loss=0.9474
# 56/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.844, accuracy03=0.961, accuracy05=0.977, loss=0.490]
# 56/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.77it/s, accuracy01=0.797, accuracy03=0.938, accuracy05=0.969, loss=0.611]
# [2020-10-17 18:12:41,764]
# 56/100 * Epoch 56 (_base): lr=0.0003 | momentum=0.9000
# 56/100 * Epoch 56 (train): accuracy01=0.8380 | accuracy03=0.9561 | accuracy05=0.9849 | loss=0.5071
# 56/100 * Epoch 56 (valid): accuracy01=0.8164 | accuracy03=0.9403 | accuracy05=0.9738 | loss=0.6017
# 57/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.70it/s, accuracy01=0.852, accuracy03=0.969, accuracy05=0.984, loss=0.513]
# 57/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.80it/s, accuracy01=0.758, accuracy03=0.945, accuracy05=0.961, loss=0.786]
# [2020-10-17 18:13:19,187]
# 57/100 * Epoch 57 (_base): lr=0.0003 | momentum=0.9000
# 57/100 * Epoch 57 (train): accuracy01=0.8302 | accuracy03=0.9570 | accuracy05=0.9833 | loss=0.5067
# 57/100 * Epoch 57 (valid): accuracy01=0.7416 | accuracy03=0.9174 | accuracy05=0.9609 | loss=0.8641
# 58/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.69it/s, accuracy01=0.828, accuracy03=0.953, accuracy05=0.992, loss=0.493]
# 58/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.76it/s, accuracy01=0.812, accuracy03=0.930, accuracy05=0.953, loss=0.696]
# [2020-10-17 18:13:56,436]
# 58/100 * Epoch 58 (_base): lr=0.0003 | momentum=0.9000
# 58/100 * Epoch 58 (train): accuracy01=0.8345 | accuracy03=0.9555 | accuracy05=0.9865 | loss=0.5013
# 58/100 * Epoch 58 (valid): accuracy01=0.7812 | accuracy03=0.9263 | accuracy05=0.9688 | loss=0.6816
# 59/100 * Epoch (train): 100% 56/56 [00:34<00:00,  1.64it/s, accuracy01=0.859, accuracy03=0.961, accuracy05=0.977, loss=0.440]
# 59/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.74it/s, accuracy01=0.789, accuracy03=0.922, accuracy05=0.953, loss=0.684]
# [2020-10-17 18:14:34,738]
# 59/100 * Epoch 59 (_base): lr=0.0003 | momentum=0.9000
# 59/100 * Epoch 59 (train): accuracy01=0.8333 | accuracy03=0.9544 | accuracy05=0.9847 | loss=0.5133
# 59/100 * Epoch 59 (valid): accuracy01=0.7846 | accuracy03=0.9358 | accuracy05=0.9727 | loss=0.6918
# 60/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.66it/s, accuracy01=0.836, accuracy03=0.977, accuracy05=0.984, loss=0.499]
# 60/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.72it/s, accuracy01=0.828, accuracy03=0.945, accuracy05=0.992, loss=0.609]
# [2020-10-17 18:15:12,637]
# 60/100 * Epoch 60 (_base): lr=0.0003 | momentum=0.9000
# 60/100 * Epoch 60 (train): accuracy01=0.8380 | accuracy03=0.9568 | accuracy05=0.9847 | loss=0.4848
# 60/100 * Epoch 60 (valid): accuracy01=0.8119 | accuracy03=0.9386 | accuracy05=0.9760 | loss=0.6403
# 61/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.69it/s, accuracy01=0.844, accuracy03=0.945, accuracy05=0.977, loss=0.448]
# 61/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.74it/s, accuracy01=0.797, accuracy03=0.922, accuracy05=0.961, loss=0.646]
# [2020-10-17 18:15:49,879]
# 61/100 * Epoch 61 (_base): lr=0.0003 | momentum=0.9000
# 61/100 * Epoch 61 (train): accuracy01=0.8500 | accuracy03=0.9601 | accuracy05=0.9872 | loss=0.4688
# 61/100 * Epoch 61 (valid): accuracy01=0.8237 | accuracy03=0.9414 | accuracy05=0.9760 | loss=0.5824
# 62/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.66it/s, accuracy01=0.898, accuracy03=0.992, accuracy05=1.000, loss=0.374]
# 62/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.76it/s, accuracy01=0.742, accuracy03=0.891, accuracy05=0.969, loss=0.709]
# [2020-10-17 18:16:28,014]
# 62/100 * Epoch 62 (_base): lr=0.0003 | momentum=0.9000
# 62/100 * Epoch 62 (train): accuracy01=0.8495 | accuracy03=0.9619 | accuracy05=0.9849 | loss=0.4609
# 62/100 * Epoch 62 (valid): accuracy01=0.7868 | accuracy03=0.9263 | accuracy05=0.9721 | loss=0.6571
# 63/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.797, accuracy03=0.953, accuracy05=0.992, loss=0.570]
# 63/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.80it/s, accuracy01=0.789, accuracy03=0.953, accuracy05=0.992, loss=0.647]
# [2020-10-17 18:17:04,999]
# 63/100 * Epoch 63 (_base): lr=0.0003 | momentum=0.9000
# 63/100 * Epoch 63 (train): accuracy01=0.8474 | accuracy03=0.9608 | accuracy05=0.9847 | loss=0.4672
# 63/100 * Epoch 63 (valid): accuracy01=0.8002 | accuracy03=0.9258 | accuracy05=0.9738 | loss=0.7006
# 64/100 * Epoch (train): 100% 56/56 [00:34<00:00,  1.64it/s, accuracy01=0.789, accuracy03=0.961, accuracy05=0.969, loss=0.574]
# 64/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.69it/s, accuracy01=0.750, accuracy03=0.906, accuracy05=0.945, loss=0.836]
# [2020-10-17 18:17:43,280]
# 64/100 * Epoch 64 (_base): lr=0.0003 | momentum=0.9000
# 64/100 * Epoch 64 (train): accuracy01=0.8546 | accuracy03=0.9648 | accuracy05=0.9855 | loss=0.4530
# 64/100 * Epoch 64 (valid): accuracy01=0.7673 | accuracy03=0.9180 | accuracy05=0.9688 | loss=0.7537
# 65/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.71it/s, accuracy01=0.844, accuracy03=0.977, accuracy05=0.992, loss=0.398]
# 65/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.78it/s, accuracy01=0.742, accuracy03=0.898, accuracy05=0.953, loss=0.937]
# [2020-10-17 18:18:20,254]
# 65/100 * Epoch 65 (_base): lr=0.0003 | momentum=0.9000
# 65/100 * Epoch 65 (train): accuracy01=0.8456 | accuracy03=0.9619 | accuracy05=0.9866 | loss=0.4710
# 65/100 * Epoch 65 (valid): accuracy01=0.7812 | accuracy03=0.9275 | accuracy05=0.9738 | loss=0.7238
# 66/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.852, accuracy03=0.961, accuracy05=0.984, loss=0.452]
# 66/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.82it/s, accuracy01=0.750, accuracy03=0.930, accuracy05=0.953, loss=0.899]
# [2020-10-17 18:18:57,305]
# 66/100 * Epoch 66 (_base): lr=0.0003 | momentum=0.9000
# 66/100 * Epoch 66 (train): accuracy01=0.8525 | accuracy03=0.9640 | accuracy05=0.9860 | loss=0.4497
# 66/100 * Epoch 66 (valid): accuracy01=0.7640 | accuracy03=0.9219 | accuracy05=0.9682 | loss=0.7962
# 67/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.875, accuracy03=0.953, accuracy05=0.984, loss=0.402]
# 67/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.70it/s, accuracy01=0.781, accuracy03=0.945, accuracy05=0.969, loss=0.640]
# [2020-10-17 18:19:34,460]
# 67/100 * Epoch 67 (_base): lr=0.0003 | momentum=0.9000
# 67/100 * Epoch 67 (train): accuracy01=0.8571 | accuracy03=0.9628 | accuracy05=0.9886 | loss=0.4393
# 67/100 * Epoch 67 (valid): accuracy01=0.7785 | accuracy03=0.9235 | accuracy05=0.9704 | loss=0.7612
# 68/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.836, accuracy03=0.938, accuracy05=0.961, loss=0.590]
# 68/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.81it/s, accuracy01=0.836, accuracy03=0.922, accuracy05=0.977, loss=0.548]
# [2020-10-17 18:20:11,559]
# 68/100 * Epoch 68 (_base): lr=0.0003 | momentum=0.9000
# 68/100 * Epoch 68 (train): accuracy01=0.8454 | accuracy03=0.9586 | accuracy05=0.9860 | loss=0.4703
# 68/100 * Epoch 68 (valid): accuracy01=0.8097 | accuracy03=0.9375 | accuracy05=0.9754 | loss=0.6372
# 69/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.820, accuracy03=0.977, accuracy05=0.992, loss=0.493]
# 69/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.71it/s, accuracy01=0.812, accuracy03=0.930, accuracy05=0.969, loss=0.646]
# [2020-10-17 18:20:48,725]
# 69/100 * Epoch 69 (_base): lr=0.0003 | momentum=0.9000
# 69/100 * Epoch 69 (train): accuracy01=0.8581 | accuracy03=0.9646 | accuracy05=0.9867 | loss=0.4419
# 69/100 * Epoch 69 (valid): accuracy01=0.8036 | accuracy03=0.9302 | accuracy05=0.9727 | loss=0.7091
# 70/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.828, accuracy03=0.922, accuracy05=0.961, loss=0.523]
# 70/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.72it/s, accuracy01=0.781, accuracy03=0.945, accuracy05=0.984, loss=0.640]
# [2020-10-17 18:21:25,920]
# 70/100 * Epoch 70 (_base): lr=0.0003 | momentum=0.9000
# 70/100 * Epoch 70 (train): accuracy01=0.8531 | accuracy03=0.9612 | accuracy05=0.9860 | loss=0.4592
# 70/100 * Epoch 70 (valid): accuracy01=0.7679 | accuracy03=0.9202 | accuracy05=0.9648 | loss=0.7979
# 71/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.70it/s, accuracy01=0.859, accuracy03=0.969, accuracy05=0.984, loss=0.472]
# 71/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.69it/s, accuracy01=0.750, accuracy03=0.922, accuracy05=0.961, loss=0.818]
# [2020-10-17 18:22:03,191]
# 71/100 * Epoch 71 (_base): lr=0.0003 | momentum=0.9000
# 71/100 * Epoch 71 (train): accuracy01=0.8539 | accuracy03=0.9594 | accuracy05=0.9848 | loss=0.4527
# 71/100 * Epoch 71 (valid): accuracy01=0.7506 | accuracy03=0.9191 | accuracy05=0.9654 | loss=0.8392
# 72/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.812, accuracy03=0.938, accuracy05=0.984, loss=0.563]
# 72/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.78it/s, accuracy01=0.781, accuracy03=0.914, accuracy05=0.961, loss=0.840]
# [2020-10-17 18:22:40,277]
# 72/100 * Epoch 72 (_base): lr=0.0003 | momentum=0.9000
# 72/100 * Epoch 72 (train): accuracy01=0.8576 | accuracy03=0.9621 | accuracy05=0.9842 | loss=0.4404
# 72/100 * Epoch 72 (valid): accuracy01=0.7695 | accuracy03=0.9275 | accuracy05=0.9715 | loss=0.7992
# 73/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.875, accuracy03=0.984, accuracy05=1.000, loss=0.378]
# 73/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.69it/s, accuracy01=0.820, accuracy03=0.922, accuracy05=0.977, loss=0.553]
# [2020-10-17 18:23:17,459]
# 73/100 * Epoch 73 (_base): lr=0.0003 | momentum=0.9000
# 73/100 * Epoch 73 (train): accuracy01=0.8595 | accuracy03=0.9600 | accuracy05=0.9863 | loss=0.4433
# 73/100 * Epoch 73 (valid): accuracy01=0.8147 | accuracy03=0.9308 | accuracy05=0.9738 | loss=0.6126
# 74/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.66it/s, accuracy01=0.852, accuracy03=0.961, accuracy05=0.984, loss=0.507]
# 74/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.74it/s, accuracy01=0.797, accuracy03=0.938, accuracy05=0.969, loss=0.652]
# [2020-10-17 18:23:55,411]
# 74/100 * Epoch 74 (_base): lr=0.0003 | momentum=0.9000
# 74/100 * Epoch 74 (train): accuracy01=0.8594 | accuracy03=0.9616 | accuracy05=0.9867 | loss=0.4376
# 74/100 * Epoch 74 (valid): accuracy01=0.7963 | accuracy03=0.9342 | accuracy05=0.9727 | loss=0.6595
# 75/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.898, accuracy03=0.977, accuracy05=0.992, loss=0.354]
# 75/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.73it/s, accuracy01=0.758, accuracy03=0.898, accuracy05=0.969, loss=0.884]
# [2020-10-17 18:24:32,542]
# 75/100 * Epoch 75 (_base): lr=0.0003 | momentum=0.9000
# 75/100 * Epoch 75 (train): accuracy01=0.8701 | accuracy03=0.9636 | accuracy05=0.9884 | loss=0.4154
# 75/100 * Epoch 75 (valid): accuracy01=0.7941 | accuracy03=0.9425 | accuracy05=0.9782 | loss=0.6878
# 76/100 * Epoch (train): 100% 56/56 [00:34<00:00,  1.62it/s, accuracy01=0.883, accuracy03=0.953, accuracy05=0.984, loss=0.403]
# 76/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.82it/s, accuracy01=0.773, accuracy03=0.922, accuracy05=0.977, loss=0.771]
# [2020-10-17 18:25:11,180]
# 76/100 * Epoch 76 (_base): lr=0.0003 | momentum=0.9000
# 76/100 * Epoch 76 (train): accuracy01=0.8584 | accuracy03=0.9616 | accuracy05=0.9833 | loss=0.4332
# 76/100 * Epoch 76 (valid): accuracy01=0.7718 | accuracy03=0.9269 | accuracy05=0.9715 | loss=0.7724
# 77/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.67it/s, accuracy01=0.859, accuracy03=0.961, accuracy05=0.977, loss=0.446]
# 77/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.77it/s, accuracy01=0.625, accuracy03=0.867, accuracy05=0.953, loss=1.176]
# [2020-10-17 18:25:48,967]
# 77/100 * Epoch 77 (_base): lr=0.0003 | momentum=0.9000
# 77/100 * Epoch 77 (train): accuracy01=0.8704 | accuracy03=0.9668 | accuracy05=0.9865 | loss=0.4129
# 77/100 * Epoch 77 (valid): accuracy01=0.7266 | accuracy03=0.8951 | accuracy05=0.9576 | loss=0.9423
# 78/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.70it/s, accuracy01=0.852, accuracy03=0.977, accuracy05=0.984, loss=0.364]
# 78/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.82it/s, accuracy01=0.703, accuracy03=0.867, accuracy05=0.945, loss=1.138]
# [2020-10-17 18:26:26,090]
# 78/100 * Epoch 78 (_base): lr=0.0003 | momentum=0.9000
# 78/100 * Epoch 78 (train): accuracy01=0.8617 | accuracy03=0.9676 | accuracy05=0.9893 | loss=0.4233
# 78/100 * Epoch 78 (valid): accuracy01=0.7182 | accuracy03=0.9018 | accuracy05=0.9648 | loss=0.9936
# 79/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.867, accuracy03=0.977, accuracy05=1.000, loss=0.388]
# 79/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.79it/s, accuracy01=0.766, accuracy03=0.922, accuracy05=0.953, loss=0.810]
# [2020-10-17 18:27:03,191]
# 79/100 * Epoch 79 (_base): lr=0.0003 | momentum=0.9000
# 79/100 * Epoch 79 (train): accuracy01=0.8680 | accuracy03=0.9637 | accuracy05=0.9856 | loss=0.4148
# 79/100 * Epoch 79 (valid): accuracy01=0.8013 | accuracy03=0.9358 | accuracy05=0.9699 | loss=0.6727
# 80/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.906, accuracy03=0.969, accuracy05=0.992, loss=0.311]
# 80/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.81it/s, accuracy01=0.773, accuracy03=0.914, accuracy05=0.953, loss=0.676]
# [2020-10-17 18:27:40,483]
# 80/100 * Epoch 80 (_base): lr=0.0003 | momentum=0.9000
# 80/100 * Epoch 80 (train): accuracy01=0.8723 | accuracy03=0.9626 | accuracy05=0.9872 | loss=0.4019
# 80/100 * Epoch 80 (valid): accuracy01=0.8237 | accuracy03=0.9470 | accuracy05=0.9799 | loss=0.5789
# 81/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.69it/s, accuracy01=0.883, accuracy03=0.977, accuracy05=0.984, loss=0.333]
# 81/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.77it/s, accuracy01=0.758, accuracy03=0.891, accuracy05=0.953, loss=1.007]
# [2020-10-17 18:28:17,975]
# 81/100 * Epoch 81 (_base): lr=0.0003 | momentum=0.9000
# 81/100 * Epoch 81 (train): accuracy01=0.8666 | accuracy03=0.9657 | accuracy05=0.9884 | loss=0.4106
# 81/100 * Epoch 81 (valid): accuracy01=0.7511 | accuracy03=0.9040 | accuracy05=0.9643 | loss=0.8748
# 82/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.71it/s, accuracy01=0.898, accuracy03=0.969, accuracy05=0.992, loss=0.324]
# 82/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.76it/s, accuracy01=0.859, accuracy03=0.930, accuracy05=0.969, loss=0.588]
# [2020-10-17 18:28:54,968]
# 82/100 * Epoch 82 (_base): lr=0.0003 | momentum=0.9000
# 82/100 * Epoch 82 (train): accuracy01=0.8580 | accuracy03=0.9629 | accuracy05=0.9859 | loss=0.4234
# 82/100 * Epoch 82 (valid): accuracy01=0.8265 | accuracy03=0.9481 | accuracy05=0.9805 | loss=0.5730
# 83/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.67it/s, accuracy01=0.773, accuracy03=0.938, accuracy05=0.977, loss=0.607]
# 83/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.70it/s, accuracy01=0.812, accuracy03=0.922, accuracy05=0.969, loss=0.650]
# [2020-10-17 18:29:33,346]
# 83/100 * Epoch 83 (_base): lr=0.0003 | momentum=0.9000
# 83/100 * Epoch 83 (train): accuracy01=0.8711 | accuracy03=0.9692 | accuracy05=0.9891 | loss=0.3974
# 83/100 * Epoch 83 (valid): accuracy01=0.7829 | accuracy03=0.9263 | accuracy05=0.9721 | loss=0.7153
# 84/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.867, accuracy03=0.953, accuracy05=0.984, loss=0.365]
# 84/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.81it/s, accuracy01=0.805, accuracy03=0.938, accuracy05=0.969, loss=0.640]
# [2020-10-17 18:30:10,463]
# 84/100 * Epoch 84 (_base): lr=0.0003 | momentum=0.9000
# 84/100 * Epoch 84 (train): accuracy01=0.8723 | accuracy03=0.9657 | accuracy05=0.9867 | loss=0.3937
# 84/100 * Epoch 84 (valid): accuracy01=0.8158 | accuracy03=0.9425 | accuracy05=0.9805 | loss=0.6122
# 85/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.891, accuracy03=0.984, accuracy05=0.992, loss=0.319]
# 85/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.79it/s, accuracy01=0.805, accuracy03=0.906, accuracy05=0.953, loss=0.730]
# [2020-10-17 18:30:47,495]
# 85/100 * Epoch 85 (_base): lr=0.0003 | momentum=0.9000
# 85/100 * Epoch 85 (train): accuracy01=0.8670 | accuracy03=0.9685 | accuracy05=0.9869 | loss=0.4060
# 85/100 * Epoch 85 (valid): accuracy01=0.7985 | accuracy03=0.9291 | accuracy05=0.9704 | loss=0.7512
# 86/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.65it/s, accuracy01=0.906, accuracy03=0.977, accuracy05=0.992, loss=0.339]
# 86/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.78it/s, accuracy01=0.781, accuracy03=0.930, accuracy05=0.969, loss=0.738]
# [2020-10-17 18:31:25,599]
# 86/100 * Epoch 86 (_base): lr=0.0003 | momentum=0.9000
# 86/100 * Epoch 86 (train): accuracy01=0.8721 | accuracy03=0.9689 | accuracy05=0.9890 | loss=0.3913
# 86/100 * Epoch 86 (valid): accuracy01=0.7907 | accuracy03=0.9414 | accuracy05=0.9782 | loss=0.7043
# 87/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.71it/s, accuracy01=0.891, accuracy03=0.969, accuracy05=1.000, loss=0.352]
# 87/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.75it/s, accuracy01=0.781, accuracy03=0.922, accuracy05=0.961, loss=0.741]
# [2020-10-17 18:32:02,904]
# 87/100 * Epoch 87 (_base): lr=0.0003 | momentum=0.9000
# 87/100 * Epoch 87 (train): accuracy01=0.8712 | accuracy03=0.9657 | accuracy05=0.9858 | loss=0.4017
# 87/100 * Epoch 87 (valid): accuracy01=0.7946 | accuracy03=0.9358 | accuracy05=0.9704 | loss=0.6904
# 88/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.867, accuracy03=0.977, accuracy05=1.000, loss=0.435]
# 88/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.77it/s, accuracy01=0.789, accuracy03=0.922, accuracy05=0.977, loss=0.727]
# [2020-10-17 18:32:40,031]
# 88/100 * Epoch 88 (_base): lr=0.0003 | momentum=0.9000
# 88/100 * Epoch 88 (train): accuracy01=0.8723 | accuracy03=0.9655 | accuracy05=0.9880 | loss=0.3882
# 88/100 * Epoch 88 (valid): accuracy01=0.8119 | accuracy03=0.9358 | accuracy05=0.9782 | loss=0.6650
# 89/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.836, accuracy03=0.969, accuracy05=0.992, loss=0.461]
# 89/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.77it/s, accuracy01=0.750, accuracy03=0.898, accuracy05=0.969, loss=0.827]
# [2020-10-17 18:33:17,175]
# 89/100 * Epoch 89 (_base): lr=0.0003 | momentum=0.9000
# 89/100 * Epoch 89 (train): accuracy01=0.8717 | accuracy03=0.9685 | accuracy05=0.9865 | loss=0.3944
# 89/100 * Epoch 89 (valid): accuracy01=0.7963 | accuracy03=0.9381 | accuracy05=0.9738 | loss=0.6696
# 90/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.867, accuracy03=0.953, accuracy05=0.977, loss=0.536]
# 90/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.76it/s, accuracy01=0.852, accuracy03=0.961, accuracy05=0.969, loss=0.479]
# [2020-10-17 18:33:54,218]
# 90/100 * Epoch 90 (_base): lr=0.0003 | momentum=0.9000
# 90/100 * Epoch 90 (train): accuracy01=0.8736 | accuracy03=0.9682 | accuracy05=0.9863 | loss=0.3772
# 90/100 * Epoch 90 (valid): accuracy01=0.8047 | accuracy03=0.9364 | accuracy05=0.9743 | loss=0.6845
# 91/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.69it/s, accuracy01=0.891, accuracy03=0.984, accuracy05=1.000, loss=0.339]
# 91/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.75it/s, accuracy01=0.797, accuracy03=0.938, accuracy05=0.977, loss=0.729]
# [2020-10-17 18:34:31,517]
# 91/100 * Epoch 91 (_base): lr=0.0003 | momentum=0.9000
# 91/100 * Epoch 91 (train): accuracy01=0.8751 | accuracy03=0.9686 | accuracy05=0.9880 | loss=0.3853
# 91/100 * Epoch 91 (valid): accuracy01=0.8170 | accuracy03=0.9470 | accuracy05=0.9788 | loss=0.6080
# 92/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.883, accuracy03=0.977, accuracy05=0.992, loss=0.339]
# 92/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.78it/s, accuracy01=0.688, accuracy03=0.875, accuracy05=0.938, loss=1.219]
# [2020-10-17 18:35:08,610]
# 92/100 * Epoch 92 (_base): lr=0.0003 | momentum=0.9000
# 92/100 * Epoch 92 (train): accuracy01=0.8786 | accuracy03=0.9706 | accuracy05=0.9891 | loss=0.3708
# 92/100 * Epoch 92 (valid): accuracy01=0.7210 | accuracy03=0.8884 | accuracy05=0.9559 | loss=1.1314
# 93/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.906, accuracy03=0.961, accuracy05=0.992, loss=0.379]
# 93/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.76it/s, accuracy01=0.828, accuracy03=0.969, accuracy05=0.969, loss=0.601]
# [2020-10-17 18:35:46,018]
# 93/100 * Epoch 93 (_base): lr=0.0003 | momentum=0.9000
# 93/100 * Epoch 93 (train): accuracy01=0.8783 | accuracy03=0.9657 | accuracy05=0.9870 | loss=0.3766
# 93/100 * Epoch 93 (valid): accuracy01=0.8008 | accuracy03=0.9420 | accuracy05=0.9760 | loss=0.6863
# 94/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.70it/s, accuracy01=0.906, accuracy03=0.961, accuracy05=0.992, loss=0.277]
# 94/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.69it/s, accuracy01=0.773, accuracy03=0.906, accuracy05=0.945, loss=0.777]
# [2020-10-17 18:36:23,170]
# 94/100 * Epoch 94 (_base): lr=0.0003 | momentum=0.9000
# 94/100 * Epoch 94 (train): accuracy01=0.8779 | accuracy03=0.9682 | accuracy05=0.9891 | loss=0.3685
# 94/100 * Epoch 94 (valid): accuracy01=0.7656 | accuracy03=0.9157 | accuracy05=0.9688 | loss=0.7856
# 95/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.67it/s, accuracy01=0.852, accuracy03=0.969, accuracy05=0.992, loss=0.448]
# 95/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.73it/s, accuracy01=0.836, accuracy03=0.961, accuracy05=0.992, loss=0.487]
# [2020-10-17 18:37:00,901]
# 95/100 * Epoch 95 (_base): lr=0.0003 | momentum=0.9000
# 95/100 * Epoch 95 (train): accuracy01=0.8795 | accuracy03=0.9711 | accuracy05=0.9900 | loss=0.3763
# 95/100 * Epoch 95 (valid): accuracy01=0.8242 | accuracy03=0.9459 | accuracy05=0.9805 | loss=0.5694
# 96/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.70it/s, accuracy01=0.883, accuracy03=0.969, accuracy05=0.992, loss=0.399]
# 96/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.76it/s, accuracy01=0.805, accuracy03=0.922, accuracy05=0.938, loss=0.796]
# [2020-10-17 18:37:38,335]
# 96/100 * Epoch 96 (_base): lr=0.0003 | momentum=0.9000
# 96/100 * Epoch 96 (train): accuracy01=0.8790 | accuracy03=0.9689 | accuracy05=0.9895 | loss=0.3612
# 96/100 * Epoch 96 (valid): accuracy01=0.8175 | accuracy03=0.9381 | accuracy05=0.9732 | loss=0.6239
# 97/100 * Epoch (train): 100% 56/56 [00:33<00:00,  1.65it/s, accuracy01=0.867, accuracy03=0.938, accuracy05=0.977, loss=0.393]
# 97/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.76it/s, accuracy01=0.781, accuracy03=0.914, accuracy05=0.969, loss=0.814]
# [2020-10-17 18:38:16,772]
# 97/100 * Epoch 97 (_base): lr=0.0003 | momentum=0.9000
# 97/100 * Epoch 97 (train): accuracy01=0.8825 | accuracy03=0.9715 | accuracy05=0.9895 | loss=0.3606
# 97/100 * Epoch 97 (valid): accuracy01=0.7796 | accuracy03=0.9280 | accuracy05=0.9732 | loss=0.7201
# 98/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.71it/s, accuracy01=0.812, accuracy03=0.938, accuracy05=0.984, loss=0.526]
# 98/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.81it/s, accuracy01=0.781, accuracy03=0.906, accuracy05=0.961, loss=0.738]
# [2020-10-17 18:38:53,719]
# 98/100 * Epoch 98 (_base): lr=0.0003 | momentum=0.9000
# 98/100 * Epoch 98 (train): accuracy01=0.8806 | accuracy03=0.9707 | accuracy05=0.9908 | loss=0.3710
# 98/100 * Epoch 98 (valid): accuracy01=0.7439 | accuracy03=0.9113 | accuracy05=0.9643 | loss=0.9194
# 99/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.71it/s, accuracy01=0.883, accuracy03=0.977, accuracy05=0.992, loss=0.338]
# 99/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.66it/s, accuracy01=0.820, accuracy03=0.953, accuracy05=0.977, loss=0.657]
# [2020-10-17 18:39:30,826]
# 99/100 * Epoch 99 (_base): lr=0.0003 | momentum=0.9000
# 99/100 * Epoch 99 (train): accuracy01=0.8823 | accuracy03=0.9681 | accuracy05=0.9869 | loss=0.3754
# 99/100 * Epoch 99 (valid): accuracy01=0.8086 | accuracy03=0.9515 | accuracy05=0.9816 | loss=0.6261
# 100/100 * Epoch (train): 100% 56/56 [00:32<00:00,  1.71it/s, accuracy01=0.867, accuracy03=0.969, accuracy05=0.992, loss=0.397]
# 100/100 * Epoch (valid): 100% 14/14 [00:03<00:00,  3.75it/s, accuracy01=0.812, accuracy03=0.922, accuracy05=0.961, loss=0.669]
# [2020-10-17 18:40:07,788]
# 100/100 * Epoch 100 (_base): lr=0.0003 | momentum=0.9000
# 100/100 * Epoch 100 (train): accuracy01=0.8750 | accuracy03=0.9681 | accuracy05=0.9891 | loss=0.3891
# 100/100 * Epoch 100 (valid): accuracy01=0.8164 | accuracy03=0.9375 | accuracy05=0.9788 | loss=0.6408
# Top best models:
# logs/20201017-173718/checkpoints/train.95.pth	0.5694
# => Loading checkpoint logs/20201017-173718/checkpoints/best_full.pth
# loaded state checkpoint logs/20201017-173718/checkpoints/best_full.pth (global epoch 95, epoch 95, stage train)

# %% [markdown]
# This code below will generate a submission.
# It reads images from `test` folder and gathers prediction from the trained model.
# Check your submission before uploading it into `Kaggle`.

# %%
submission = {"Id": [], "Category": []}
model.eval()

test_dataset = create_dataset(dirs=f"{path_to_dataset}/test", extension="*.jpg")
test_data = list({"filepath": filepath} for filepath in test_dataset["test"])

test_open_fn = ReaderCompose(
    [
        ImageReader(
            input_key="filepath", output_key="features", rootpath=""
        ),
        ScalarReader(
            input_key="filepath",
            output_key="filepath",
            default_value="",
            dtype=str,
        ),
    ]
)

test_loader = utils.get_loader(
    test_data,
    open_fn=test_open_fn,
    dict_transform=valid_data_transform,
    batch_size=batch_size,
    num_workers=num_workers,
    shuffle=False,
    sampler=None,
    drop_last=False,
)

for prediction in runner.predict_loader(loader=test_loader):
    prediction["labels"] = [class_names[c] for c in torch.max(prediction["log_probs"], axis=1)[1]]
    submission["Id"].extend(Path(f).stem for f in prediction["filepath"])
    submission["Category"].extend(prediction["labels"])

# %%
pd.DataFrame(submission).to_csv(f"sub_cls_{str(datetime.now().strftime('%Y%m%d-%H%M%S'))}.csv", index=False)
